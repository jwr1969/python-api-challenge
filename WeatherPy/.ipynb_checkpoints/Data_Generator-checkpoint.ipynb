# %%
# Create a city list based on random coordinates. Dict or DataFrame? Name, Country, lat, long, Found
# List needs to be very long as we'd expect weather not to find all cities in [OpenWeatherMap API](https://openweathermap.org/api)
# Query open weather map and get Temperature (F), Humidity (%) vs. Latitude, Cloudiness (%), Wind Speed (mph)
# Check coordinates to ensure we got the right city

# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
from scipy import stats
import datetime
from scipy.stats import linregress
# weather_api_key = "35fb1a4a0c59eb148a4297ff5695ccd4"

# %%
# Create a DataFrame to hold the data
df_weather_data = pd.DataFrame(index=[0])
df_weather_data["City"] = ""
df_weather_data["Country_Code"] = ""
df_weather_data["Input_Lat"] = ""
df_weather_data["Input_Lon"] = ""
df_weather_data["Actual_Lat"] = ""
df_weather_data["Actual_Lon"] = ""
df_weather_data["MaxTemp"] = ""
df_weather_data["Humidity"] = ""
df_weather_data["Cloudiness"] = ""
df_weather_data["Wind_Speed"] = ""
df_weather_data["Date_Time"] = ""

# %%
# Create a city list based on random coordinates
# Create random coordinates - more than 500 in case of "failures"
lat = np.random.randint(low=-90, high=90, size=2000)
lon = np.random.randint(low=-180, high=180, size=2000)
# Weather url
url = "http://api.openweathermap.org/data/2.5/weather?"
# Find nearest cities
# for x in range(len(lat)):
x = 0
a = 0
skipped = 0
while a < 500:
    city = citipy.nearest_city(lat[x],lon[x])
    city_name = city.city_name
    city_country = city.country_code
    
    # Build query url
    query_url = url + "appid=" + "35fb1a4a0c59eb148a4297ff5695ccd4" + "&q=" + city_name + "&units=imperial"
    
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    print(f"Attempt #{x}: Trying {city_name} in {city_country}  ", end = "")
    
    try:  
    
        df_weather_data.loc[x,"Actual_Lat"] = weather_json["coord"]["lat"]
        df_weather_data.loc[x,"Actual_Lon"] = weather_json["coord"]["lon"]
        df_weather_data.loc[x,"MaxTemp"] = weather_json["main"]["temp_max"]
        df_weather_data.loc[x,"Humidity"] = weather_json["main"]["humidity"]
        df_weather_data.loc[x,"Cloudiness"] = weather_json["clouds"]["all"]
        df_weather_data.loc[x,"Wind_Speed"] = weather_json["wind"]["speed"]
        
        my_timestamp = weather_json["dt"]
        my_dt = datetime.datetime.fromtimestamp(my_timestamp)       
        date_time = f"{my_dt.month}/{my_dt.day}/{my_dt.year} - {my_dt.hour}:{my_dt.minute}:{my_dt.second}"
  
        df_weather_data.loc[x,"Date_Time"] = date_time
        
        df_weather_data.loc[x,"City"] = city_name
        df_weather_data.loc[x,"Country_Code"] = weather_json["sys"]["country"]
        df_weather_data.loc[x,"Input_Lat"] = lat[x]
        df_weather_data.loc[x,"Input_Lon"] = lon[x]
        
        print(f"Success!")
        
       
    
    except (KeyError):
        
        skipped +=1
        print("Ouch! Missing field/result... skipping.")
#         if x == 0:
#             x = -1
#         else:
#             pass
    
    if (x > 10) & (x % 50 == 0):
        df_weather_data.drop_duplicates(subset=["City","Actual_Lat","Actual_Lon"], inplace=True)
        a = df_weather_data["City"].count()
        print("---------------------------------")
        print(f"Checking for duplicates.....resetting counter: {a}")
        print("---------------------------------")
        
        
    
    x +=1
    

    
print("----------------------------------------------")
print("End of run summary statistics")
print(f"Total records: {a}")
print(f"Number of requests returning no results: {skipped}")
print(f"Number of duplicates removed: {((x-skipped))-a}")
# Out:
# Attempt #0: Trying rundu in na  Success!
# Attempt #1: Trying ushuaia in ar  Success!
# Attempt #2: Trying chuy in uy  Success!
# Attempt #3: Trying pevek in ru  Success!
# Attempt #4: Trying mogzon in ru  Success!
# Attempt #5: Trying cape town in za  Success!
# Attempt #6: Trying ushuaia in ar  Success!
# Attempt #7: Trying rikitea in pf  Success!
# Attempt #8: Trying punta arenas in cl  Success!
# Attempt #9: Trying mataura in pf  Success!
# Attempt #10: Trying qaanaaq in gl  Success!
# Attempt #11: Trying rikitea in pf  Success!
# Attempt #12: Trying slantsy in ru  Success!
# Attempt #13: Trying sanghar in pk  Success!
# Attempt #14: Trying mahajanga in mg  Success!
# Attempt #15: Trying butaritari in ki  Success!
# Attempt #16: Trying codrington in ag  Success!
# Attempt #17: Trying albany in au  Success!
# Attempt #18: Trying punta arenas in cl  Success!
# Attempt #19: Trying araouane in ml  Success!
# Attempt #20: Trying umzimvubu in za  Ouch! Missing field/result... skipping.
# Attempt #21: Trying ushuaia in ar  Success!
# Attempt #22: Trying new norfolk in au  Success!
# Attempt #23: Trying hithadhoo in mv  Success!
# Attempt #24: Trying natal in br  Success!
# Attempt #25: Trying andenes in no  Success!
# Attempt #26: Trying vaini in to  Success!
# Attempt #27: Trying bredasdorp in za  Success!
# Attempt #28: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #29: Trying rabaul in pg  Success!
# Attempt #30: Trying maridi in sd  Success!
# Attempt #31: Trying palmer in us  Success!
# Attempt #32: Trying new norfolk in au  Success!
# Attempt #33: Trying berlevag in no  Success!
# Attempt #34: Trying korem in et  Success!
# Attempt #35: Trying victoria in sc  Success!
# Attempt #36: Trying samusu in ws  Ouch! Missing field/result... skipping.
# Attempt #37: Trying nizhneyansk in ru  Ouch! Missing field/result... skipping.
# Attempt #38: Trying ust-kamchatsk in ru  Ouch! Missing field/result... skipping.
# Attempt #39: Trying atuona in pf  Success!
# Attempt #40: Trying mataura in pf  Success!
# Attempt #41: Trying arlit in ne  Success!
# Attempt #42: Trying emba in kz  Success!
# Attempt #43: Trying san carlos de bariloche in ar  Success!
# Attempt #44: Trying tomohon in id  Success!
# Attempt #45: Trying hilo in us  Success!
# Attempt #46: Trying rikitea in pf  Success!
# Attempt #47: Trying rikitea in pf  Success!
# Attempt #48: Trying chernyy yar in ru  Success!
# Attempt #49: Trying dharur in in  Success!
# Attempt #50: Trying thinadhoo in mv  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 38
# ---------------------------------
# Attempt #51: Trying saldanha in za  Success!
# Attempt #52: Trying albany in au  Success!
# Attempt #53: Trying trairi in br  Success!
# Attempt #54: Trying saint george in bm  Success!
# Attempt #55: Trying mar del plata in ar  Success!
# Attempt #56: Trying belyy yar in ru  Success!
# Attempt #57: Trying albany in au  Success!
# Attempt #58: Trying mahalapye in bw  Success!
# Attempt #59: Trying hermanus in za  Success!
# Attempt #60: Trying niigata in jp  Success!
# Attempt #61: Trying manosque in fr  Success!
# Attempt #62: Trying kapaa in us  Success!
# Attempt #63: Trying ron phibun in th  Success!
# Attempt #64: Trying flinders in au  Success!
# Attempt #65: Trying carnarvon in au  Success!
# Attempt #66: Trying anadyr in ru  Success!
# Attempt #67: Trying guerrero negro in mx  Success!
# Attempt #68: Trying obeliai in lt  Success!
# Attempt #69: Trying yulara in au  Success!
# Attempt #70: Trying leningradskiy in ru  Success!
# Attempt #71: Trying sioux lookout in ca  Success!
# Attempt #72: Trying ivybridge in gb  Success!
# Attempt #73: Trying tsihombe in mg  Ouch! Missing field/result... skipping.
# Attempt #74: Trying cabrero in cl  Success!
# Attempt #75: Trying mataura in pf  Success!
# Attempt #76: Trying bethel in us  Success!
# Attempt #77: Trying atuona in pf  Success!
# Attempt #78: Trying kitob in uz  Success!
# Attempt #79: Trying naze in jp  Success!
# Attempt #80: Trying cape town in za  Success!
# Attempt #81: Trying codrington in ag  Success!
# Attempt #82: Trying lompoc in us  Success!
# Attempt #83: Trying mount gambier in au  Success!
# Attempt #84: Trying pangnirtung in ca  Success!
# Attempt #85: Trying kalyazin in ru  Success!
# Attempt #86: Trying rikitea in pf  Success!
# Attempt #87: Trying sola in vu  Success!
# Attempt #88: Trying punta arenas in cl  Success!
# Attempt #89: Trying svetlogorsk in ru  Success!
# Attempt #90: Trying rikitea in pf  Success!
# Attempt #91: Trying busselton in au  Success!
# Attempt #92: Trying gamba in ga  Success!
# Attempt #93: Trying atuona in pf  Success!
# Attempt #94: Trying torbay in ca  Success!
# Attempt #95: Trying victoria in sc  Success!
# Attempt #96: Trying mahebourg in mu  Success!
# Attempt #97: Trying mataura in pf  Success!
# Attempt #98: Trying ushuaia in ar  Success!
# Attempt #99: Trying kadungora in id  Success!
# Attempt #100: Trying bredasdorp in za  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 73
# ---------------------------------
# Attempt #101: Trying northam in au  Success!
# Attempt #102: Trying bengkulu in id  Success!
# Attempt #103: Trying yungkang in tw  Ouch! Missing field/result... skipping.
# Attempt #104: Trying port blair in in  Success!
# Attempt #105: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #106: Trying mehamn in no  Success!
# Attempt #107: Trying saint-augustin in ca  Success!
# Attempt #108: Trying cape town in za  Success!
# Attempt #109: Trying bluff in nz  Success!
# Attempt #110: Trying yulara in au  Success!
# Attempt #111: Trying dikson in ru  Success!
# Attempt #112: Trying greenville in us  Success!
# Attempt #113: Trying tuktoyaktuk in ca  Success!
# Attempt #114: Trying barrow in us  Success!
# Attempt #115: Trying auki in sb  Success!
# Attempt #116: Trying qaanaaq in gl  Success!
# Attempt #117: Trying punta arenas in cl  Success!
# Attempt #118: Trying cabo san lucas in mx  Success!
# Attempt #119: Trying chitral in pk  Success!
# Attempt #120: Trying cape town in za  Success!
# Attempt #121: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #122: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #123: Trying bambous virieux in mu  Success!
# Attempt #124: Trying lazaro cardenas in mx  Success!
# Attempt #125: Trying jamestown in sh  Success!
# Attempt #126: Trying troitskiy in ru  Success!
# Attempt #127: Trying nelson bay in au  Success!
# Attempt #128: Trying ushuaia in ar  Success!
# Attempt #129: Trying victoria in us  Success!
# Attempt #130: Trying krasnovka in ru  Success!
# Attempt #131: Trying krasnoselkup in ru  Success!
# Attempt #132: Trying codrington in ag  Success!
# Attempt #133: Trying mar del plata in ar  Success!
# Attempt #134: Trying saint anthony in ca  Success!
# Attempt #135: Trying iskateley in ru  Success!
# Attempt #136: Trying tiksi in ru  Success!
# Attempt #137: Trying ushuaia in ar  Success!
# Attempt #138: Trying hilo in us  Success!
# Attempt #139: Trying ushuaia in ar  Success!
# Attempt #140: Trying punta arenas in cl  Success!
# Attempt #141: Trying castro in cl  Success!
# Attempt #142: Trying gasa in bt  Success!
# Attempt #143: Trying east london in za  Success!
# Attempt #144: Trying bambous virieux in mu  Success!
# Attempt #145: Trying aswan in eg  Success!
# Attempt #146: Trying cape town in za  Success!
# Attempt #147: Trying atuona in pf  Success!
# Attempt #148: Trying busselton in au  Success!
# Attempt #149: Trying bluff in nz  Success!
# Attempt #150: Trying hithadhoo in mv  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 100
# ---------------------------------
# Attempt #151: Trying kapaa in us  Success!
# Attempt #152: Trying khuldabad in in  Success!
# Attempt #153: Trying tuktoyaktuk in ca  Success!
# Attempt #154: Trying houma in us  Success!
# Attempt #155: Trying atuona in pf  Success!
# Attempt #156: Trying severo-kurilsk in ru  Success!
# Attempt #157: Trying new norfolk in au  Success!
# Attempt #158: Trying linguere in sn  Success!
# Attempt #159: Trying port lincoln in au  Success!
# Attempt #160: Trying mataura in pf  Success!
# Attempt #161: Trying bredasdorp in za  Success!
# Attempt #162: Trying albany in au  Success!
# Attempt #163: Trying vaini in to  Success!
# Attempt #164: Trying thompson in ca  Success!
# Attempt #165: Trying atuona in pf  Success!
# Attempt #166: Trying guerrero negro in mx  Success!
# Attempt #167: Trying albany in au  Success!
# Attempt #168: Trying luderitz in na  Success!
# Attempt #169: Trying ponta do sol in pt  Success!
# Attempt #170: Trying cape town in za  Success!
# Attempt #171: Trying camacha in pt  Success!
# Attempt #172: Trying cape town in za  Success!
# Attempt #173: Trying eureka in us  Success!
# Attempt #174: Trying ushuaia in ar  Success!
# Attempt #175: Trying lavrentiya in ru  Success!
# Attempt #176: Trying hilo in us  Success!
# Attempt #177: Trying victoria point in au  Success!
# Attempt #178: Trying rikitea in pf  Success!
# Attempt #179: Trying mombetsu in jp  Success!
# Attempt #180: Trying saint george in bm  Success!
# Attempt #181: Trying cherskiy in ru  Success!
# Attempt #182: Trying tuatapere in nz  Success!
# Attempt #183: Trying severo-kurilsk in ru  Success!
# Attempt #184: Trying busselton in au  Success!
# Attempt #185: Trying talnakh in ru  Success!
# Attempt #186: Trying esperance in au  Success!
# Attempt #187: Trying palmer in us  Success!
# Attempt #188: Trying gat in ly  Success!
# Attempt #189: Trying beloha in mg  Success!
# Attempt #190: Trying chuy in uy  Success!
# Attempt #191: Trying port elizabeth in za  Success!
# Attempt #192: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #193: Trying teguise in es  Success!
# Attempt #194: Trying codrington in ag  Success!
# Attempt #195: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #196: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #197: Trying kavaratti in in  Success!
# Attempt #198: Trying busselton in au  Success!
# Attempt #199: Trying geraldton in au  Success!
# Attempt #200: Trying albany in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 123
# ---------------------------------
# Attempt #201: Trying port blair in in  Success!
# Attempt #202: Trying port blair in in  Success!
# Attempt #203: Trying portland in au  Success!
# Attempt #204: Trying sovetskiy in ru  Success!
# Attempt #205: Trying cotonou in bj  Success!
# Attempt #206: Trying aksarka in ru  Success!
# Attempt #207: Trying alofi in nu  Success!
# Attempt #208: Trying odienne in ci  Success!
# Attempt #209: Trying port alfred in za  Success!
# Attempt #210: Trying norman wells in ca  Success!
# Attempt #211: Trying bluff in nz  Success!
# Attempt #212: Trying cape town in za  Success!
# Attempt #213: Trying manikpur in in  Success!
# Attempt #214: Trying hobyo in so  Success!
# Attempt #215: Trying grimshaw in ca  Success!
# Attempt #216: Trying saint-philippe in re  Success!
# Attempt #217: Trying port alfred in za  Success!
# Attempt #218: Trying vardo in no  Success!
# Attempt #219: Trying quatre cocos in mu  Success!
# Attempt #220: Trying ushuaia in ar  Success!
# Attempt #221: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #222: Trying yumen in cn  Success!
# Attempt #223: Trying padang in id  Success!
# Attempt #224: Trying tura in ru  Success!
# Attempt #225: Trying jati in pk  Success!
# Attempt #226: Trying monte alegre de minas in br  Success!
# Attempt #227: Trying puerto ayora in ec  Success!
# Attempt #228: Trying krasnoyarsk in ru  Success!
# Attempt #229: Trying khani in ru  Success!
# Attempt #230: Trying albany in au  Success!
# Attempt #231: Trying arraial do cabo in br  Success!
# Attempt #232: Trying yellowknife in ca  Success!
# Attempt #233: Trying tazmalt in dz  Success!
# Attempt #234: Trying berlevag in no  Success!
# Attempt #235: Trying east london in za  Success!
# Attempt #236: Trying sola in vu  Success!
# Attempt #237: Trying ushuaia in ar  Success!
# Attempt #238: Trying la union in cl  Success!
# Attempt #239: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #240: Trying kandrian in pg  Success!
# Attempt #241: Trying lorengau in pg  Success!
# Attempt #242: Trying esfahan in ir  Success!
# Attempt #243: Trying ushuaia in ar  Success!
# Attempt #244: Trying saint-georges in gf  Success!
# Attempt #245: Trying kapaa in us  Success!
# Attempt #246: Trying rikitea in pf  Success!
# Attempt #247: Trying east london in za  Success!
# Attempt #248: Trying rikitea in pf  Success!
# Attempt #249: Trying mataura in pf  Success!
# Attempt #250: Trying grand gaube in mu  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 154
# ---------------------------------
# Attempt #251: Trying ushuaia in ar  Success!
# Attempt #252: Trying arraial do cabo in br  Success!
# Attempt #253: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #254: Trying kaitangata in nz  Success!
# Attempt #255: Trying kieta in pg  Success!
# Attempt #256: Trying new norfolk in au  Success!
# Attempt #257: Trying chokurdakh in ru  Success!
# Attempt #258: Trying avarua in ck  Success!
# Attempt #259: Trying hermanus in za  Success!
# Attempt #260: Trying hobart in au  Success!
# Attempt #261: Trying busselton in au  Success!
# Attempt #262: Trying chokurdakh in ru  Success!
# Attempt #263: Trying bredasdorp in za  Success!
# Attempt #264: Trying bredasdorp in za  Success!
# Attempt #265: Trying gat in ly  Success!
# Attempt #266: Trying hithadhoo in mv  Success!
# Attempt #267: Trying cape town in za  Success!
# Attempt #268: Trying rikitea in pf  Success!
# Attempt #269: Trying victoria in sc  Success!
# Attempt #270: Trying qaanaaq in gl  Success!
# Attempt #271: Trying zhigalovo in ru  Success!
# Attempt #272: Trying araouane in ml  Success!
# Attempt #273: Trying rikitea in pf  Success!
# Attempt #274: Trying grindavik in is  Success!
# Attempt #275: Trying coihaique in cl  Success!
# Attempt #276: Trying amderma in ru  Ouch! Missing field/result... skipping.
# Attempt #277: Trying rungata in ki  Ouch! Missing field/result... skipping.
# Attempt #278: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #279: Trying bethel in us  Success!
# Attempt #280: Trying visby in se  Success!
# Attempt #281: Trying georgetown in sh  Success!
# Attempt #282: Trying tutoia in br  Success!
# Attempt #283: Trying yellowknife in ca  Success!
# Attempt #284: Trying henties bay in na  Success!
# Attempt #285: Trying hermanus in za  Success!
# Attempt #286: Trying xining in cn  Success!
# Attempt #287: Trying mar del plata in ar  Success!
# Attempt #288: Trying purna in in  Success!
# Attempt #289: Trying cape town in za  Success!
# Attempt #290: Trying klaksvik in fo  Success!
# Attempt #291: Trying puerto ayora in ec  Success!
# Attempt #292: Trying qaanaaq in gl  Success!
# Attempt #293: Trying saskylakh in ru  Success!
# Attempt #294: Trying rancho palos verdes in us  Success!
# Attempt #295: Trying gorontalo in id  Success!
# Attempt #296: Trying chagda in ru  Ouch! Missing field/result... skipping.
# Attempt #297: Trying dikson in ru  Success!
# Attempt #298: Trying japura in br  Success!
# Attempt #299: Trying uppsala in se  Success!
# Attempt #300: Trying kodiak in us  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 175
# ---------------------------------
# Attempt #301: Trying rikitea in pf  Success!
# Attempt #302: Trying huilong in cn  Success!
# Attempt #303: Trying albany in au  Success!
# Attempt #304: Trying jaguarari in br  Success!
# Attempt #305: Trying shimoda in jp  Success!
# Attempt #306: Trying ushuaia in ar  Success!
# Attempt #307: Trying qaanaaq in gl  Success!
# Attempt #308: Trying new norfolk in au  Success!
# Attempt #309: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #310: Trying coquimbo in cl  Success!
# Attempt #311: Trying san patricio in mx  Success!
# Attempt #312: Trying atuona in pf  Success!
# Attempt #313: Trying naze in jp  Success!
# Attempt #314: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #315: Trying hobart in au  Success!
# Attempt #316: Trying homer in us  Success!
# Attempt #317: Trying banjar in id  Success!
# Attempt #318: Trying port lincoln in au  Success!
# Attempt #319: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #320: Trying saint-philippe in re  Success!
# Attempt #321: Trying hermanus in za  Success!
# Attempt #322: Trying carnarvon in au  Success!
# Attempt #323: Trying nizhneyansk in ru  Ouch! Missing field/result... skipping.
# Attempt #324: Trying albany in au  Success!
# Attempt #325: Trying port hardy in ca  Success!
# Attempt #326: Trying busselton in au  Success!
# Attempt #327: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #328: Trying khorion in gr  Ouch! Missing field/result... skipping.
# Attempt #329: Trying vila franca do campo in pt  Success!
# Attempt #330: Trying ust-barguzin in ru  Success!
# Attempt #331: Trying cukai in my  Success!
# Attempt #332: Trying vaini in to  Success!
# Attempt #333: Trying vaini in to  Success!
# Attempt #334: Trying busselton in au  Success!
# Attempt #335: Trying praia da vitoria in pt  Success!
# Attempt #336: Trying swellendam in za  Success!
# Attempt #337: Trying sault sainte marie in ca  Success!
# Attempt #338: Trying muroto in jp  Success!
# Attempt #339: Trying atuona in pf  Success!
# Attempt #340: Trying rocha in uy  Success!
# Attempt #341: Trying carnarvon in au  Success!
# Attempt #342: Trying mataura in pf  Success!
# Attempt #343: Trying namibe in ao  Success!
# Attempt #344: Trying bongandanga in cd  Success!
# Attempt #345: Trying lompoc in us  Success!
# Attempt #346: Trying port macquarie in au  Success!
# Attempt #347: Trying hobart in au  Success!
# Attempt #348: Trying ushuaia in ar  Success!
# Attempt #349: Trying amapa in br  Success!
# Attempt #350: Trying dikson in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 195
# ---------------------------------
# Attempt #351: Trying namibe in ao  Success!
# Attempt #352: Trying mar del plata in ar  Success!
# Attempt #353: Trying atuona in pf  Success!
# Attempt #354: Trying vaini in to  Success!
# Attempt #355: Trying luwingu in zm  Success!
# Attempt #356: Trying avarua in ck  Success!
# Attempt #357: Trying airai in pw  Success!
# Attempt #358: Trying le port in re  Success!
# Attempt #359: Trying new norfolk in au  Success!
# Attempt #360: Trying east london in za  Success!
# Attempt #361: Trying mataura in pf  Success!
# Attempt #362: Trying rikitea in pf  Success!
# Attempt #363: Trying egvekinot in ru  Success!
# Attempt #364: Trying tiksi in ru  Success!
# Attempt #365: Trying narsaq in gl  Success!
# Attempt #366: Trying norman wells in ca  Success!
# Attempt #367: Trying jamestown in sh  Success!
# Attempt #368: Trying padang in id  Success!
# Attempt #369: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #370: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #371: Trying kirakira in sb  Success!
# Attempt #372: Trying mocambique in mz  Ouch! Missing field/result... skipping.
# Attempt #373: Trying mar del plata in ar  Success!
# Attempt #374: Trying bredasdorp in za  Success!
# Attempt #375: Trying shunyi in cn  Success!
# Attempt #376: Trying ponta do sol in cv  Success!
# Attempt #377: Trying new norfolk in au  Success!
# Attempt #378: Trying mareeba in au  Success!
# Attempt #379: Trying tautira in pf  Success!
# Attempt #380: Trying homer in us  Success!
# Attempt #381: Trying rikitea in pf  Success!
# Attempt #382: Trying korla in cn  Success!
# Attempt #383: Trying gumdag in tm  Success!
# Attempt #384: Trying albany in au  Success!
# Attempt #385: Trying leh in in  Success!
# Attempt #386: Trying hithadhoo in mv  Success!
# Attempt #387: Trying saint-philippe in re  Success!
# Attempt #388: Trying mataura in pf  Success!
# Attempt #389: Trying morant bay in jm  Success!
# Attempt #390: Trying angoram in pg  Success!
# Attempt #391: Trying cape town in za  Success!
# Attempt #392: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #393: Trying dingle in ie  Success!
# Attempt #394: Trying busselton in au  Success!
# Attempt #395: Trying ushuaia in ar  Success!
# Attempt #396: Trying arraial do cabo in br  Success!
# Attempt #397: Trying vaini in to  Success!
# Attempt #398: Trying bethel in us  Success!
# Attempt #399: Trying ancud in cl  Success!
# Attempt #400: Trying vaini in to  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 211
# ---------------------------------
# Attempt #401: Trying urumqi in cn  Success!
# Attempt #402: Trying mataura in pf  Success!
# Attempt #403: Trying saint-philippe in re  Success!
# Attempt #404: Trying busselton in au  Success!
# Attempt #405: Trying new norfolk in au  Success!
# Attempt #406: Trying iqaluit in ca  Success!
# Attempt #407: Trying atuona in pf  Success!
# Attempt #408: Trying cabo san lucas in mx  Success!
# Attempt #409: Trying mahebourg in mu  Success!
# Attempt #410: Trying new norfolk in au  Success!
# Attempt #411: Trying busselton in au  Success!
# Attempt #412: Trying hermanus in za  Success!
# Attempt #413: Trying westport in ie  Success!
# Attempt #414: Trying kodiak in us  Success!
# Attempt #415: Trying hermanus in za  Success!
# Attempt #416: Trying cabo san lucas in mx  Success!
# Attempt #417: Trying dikson in ru  Success!
# Attempt #418: Trying kodiak in us  Success!
# Attempt #419: Trying busselton in au  Success!
# Attempt #420: Trying soyo in ao  Success!
# Attempt #421: Trying saldanha in za  Success!
# Attempt #422: Trying castro in cl  Success!
# Attempt #423: Trying punta arenas in cl  Success!
# Attempt #424: Trying chaihe in cn  Success!
# Attempt #425: Trying la rioja in ar  Success!
# Attempt #426: Trying samalaeulu in ws  Ouch! Missing field/result... skipping.
# Attempt #427: Trying souillac in mu  Success!
# Attempt #428: Trying naze in jp  Success!
# Attempt #429: Trying bluff in nz  Success!
# Attempt #430: Trying port blair in in  Success!
# Attempt #431: Trying christchurch in nz  Success!
# Attempt #432: Trying rikitea in pf  Success!
# Attempt #433: Trying jiayuguan in cn  Success!
# Attempt #434: Trying mirnyy in ru  Success!
# Attempt #435: Trying ambilobe in mg  Success!
# Attempt #436: Trying chapais in ca  Success!
# Attempt #437: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #438: Trying hongjiang in cn  Success!
# Attempt #439: Trying provideniya in ru  Success!
# Attempt #440: Trying georgetown in sh  Success!
# Attempt #441: Trying lorengau in pg  Success!
# Attempt #442: Trying punta arenas in cl  Success!
# Attempt #443: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #444: Trying faanui in pf  Success!
# Attempt #445: Trying isla mujeres in mx  Success!
# Attempt #446: Trying punta arenas in cl  Success!
# Attempt #447: Trying arraial do cabo in br  Success!
# Attempt #448: Trying port alfred in za  Success!
# Attempt #449: Trying ponta do sol in cv  Success!
# Attempt #450: Trying bambous virieux in mu  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 227
# ---------------------------------
# Attempt #451: Trying cayenne in gf  Success!
# Attempt #452: Trying ushuaia in ar  Success!
# Attempt #453: Trying rikitea in pf  Success!
# Attempt #454: Trying cape town in za  Success!
# Attempt #455: Trying luderitz in na  Success!
# Attempt #456: Trying susanville in us  Success!
# Attempt #457: Trying tuktoyaktuk in ca  Success!
# Attempt #458: Trying cherskiy in ru  Success!
# Attempt #459: Trying dolbeau in ca  Ouch! Missing field/result... skipping.
# Attempt #460: Trying asau in tv  Success!
# Attempt #461: Trying kapaa in us  Success!
# Attempt #462: Trying cape town in za  Success!
# Attempt #463: Trying kapaa in us  Success!
# Attempt #464: Trying tuktoyaktuk in ca  Success!
# Attempt #465: Trying haridwar in in  Success!
# Attempt #466: Trying the valley in ai  Success!
# Attempt #467: Trying rikitea in pf  Success!
# Attempt #468: Trying ancud in cl  Success!
# Attempt #469: Trying cape town in za  Success!
# Attempt #470: Trying provideniya in ru  Success!
# Attempt #471: Trying hithadhoo in mv  Success!
# Attempt #472: Trying atuona in pf  Success!
# Attempt #473: Trying bengkulu in id  Success!
# Attempt #474: Trying puerto ayora in ec  Success!
# Attempt #475: Trying banda aceh in id  Success!
# Attempt #476: Trying nuzvid in in  Success!
# Attempt #477: Trying umzimvubu in za  Ouch! Missing field/result... skipping.
# Attempt #478: Trying alofi in nu  Success!
# Attempt #479: Trying santa rosalia in mx  Success!
# Attempt #480: Trying arraial do cabo in br  Success!
# Attempt #481: Trying belmonte in br  Success!
# Attempt #482: Trying tsihombe in mg  Ouch! Missing field/result... skipping.
# Attempt #483: Trying punta arenas in cl  Success!
# Attempt #484: Trying san antonio in cl  Success!
# Attempt #485: Trying punta arenas in cl  Success!
# Attempt #486: Trying koungheul in sn  Success!
# Attempt #487: Trying victoria in sc  Success!
# Attempt #488: Trying hervey bay in au  Success!
# Attempt #489: Trying ponta do sol in cv  Success!
# Attempt #490: Trying capinota in bo  Success!
# Attempt #491: Trying chapais in ca  Success!
# Attempt #492: Trying qaanaaq in gl  Success!
# Attempt #493: Trying cape town in za  Success!
# Attempt #494: Trying tuatapere in nz  Success!
# Attempt #495: Trying albany in au  Success!
# Attempt #496: Trying provideniya in ru  Success!
# Attempt #497: Trying cape town in za  Success!
# Attempt #498: Trying port victoria in ke  Success!
# Attempt #499: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #500: Trying port alfred in za  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 241
# ---------------------------------
# Attempt #501: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #502: Trying bandar-e lengeh in ir  Success!
# Attempt #503: Trying busselton in au  Success!
# Attempt #504: Trying kahului in us  Success!
# Attempt #505: Trying punta arenas in cl  Success!
# Attempt #506: Trying nanakuli in us  Success!
# Attempt #507: Trying san quintin in mx  Success!
# Attempt #508: Trying san quintin in mx  Success!
# Attempt #509: Trying ushuaia in ar  Success!
# Attempt #510: Trying port hedland in au  Success!
# Attempt #511: Trying punta arenas in cl  Success!
# Attempt #512: Trying barrow in us  Success!
# Attempt #513: Trying kapaa in us  Success!
# Attempt #514: Trying nikolskoye in ru  Success!
# Attempt #515: Trying hobart in au  Success!
# Attempt #516: Trying eisenberg in de  Success!
# Attempt #517: Trying khovu-aksy in ru  Success!
# Attempt #518: Trying yellowknife in ca  Success!
# Attempt #519: Trying saldanha in za  Success!
# Attempt #520: Trying mazamitla in mx  Success!
# Attempt #521: Trying ixtapa in mx  Success!
# Attempt #522: Trying verkhoturye in ru  Success!
# Attempt #523: Trying rikitea in pf  Success!
# Attempt #524: Trying rikitea in pf  Success!
# Attempt #525: Trying humaita in br  Success!
# Attempt #526: Trying seybaplaya in mx  Success!
# Attempt #527: Trying sangar in ru  Success!
# Attempt #528: Trying castro in cl  Success!
# Attempt #529: Trying muros in es  Success!
# Attempt #530: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #531: Trying fevralsk in ru  Ouch! Missing field/result... skipping.
# Attempt #532: Trying thompson in ca  Success!
# Attempt #533: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #534: Trying fortuna in us  Success!
# Attempt #535: Trying ushuaia in ar  Success!
# Attempt #536: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #537: Trying cape town in za  Success!
# Attempt #538: Trying treinta y tres in uy  Success!
# Attempt #539: Trying vaitupu in wf  Ouch! Missing field/result... skipping.
# Attempt #540: Trying kununurra in au  Success!
# Attempt #541: Trying souillac in mu  Success!
# Attempt #542: Trying new norfolk in au  Success!
# Attempt #543: Trying umtata in za  Success!
# Attempt #544: Trying los llanos de aridane in es  Success!
# Attempt #545: Trying gat in ly  Success!
# Attempt #546: Trying port elizabeth in za  Success!
# Attempt #547: Trying christchurch in nz  Success!
# Attempt #548: Trying sioux lookout in ca  Success!
# Attempt #549: Trying nuuk in gl  Success!
# Attempt #550: Trying namibe in ao  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 262
# ---------------------------------
# Attempt #551: Trying shiyan in cn  Success!
# Attempt #552: Trying lorengau in pg  Success!
# Attempt #553: Trying hilo in us  Success!
# Attempt #554: Trying sechura in pe  Success!
# Attempt #555: Trying severo-kurilsk in ru  Success!
# Attempt #556: Trying sitka in us  Success!
# Attempt #557: Trying kapaa in us  Success!
# Attempt #558: Trying carnarvon in au  Success!
# Attempt #559: Trying manaus in br  Success!
# Attempt #560: Trying okhotsk in ru  Success!
# Attempt #561: Trying gazojak in tm  Success!
# Attempt #562: Trying souillac in mu  Success!
# Attempt #563: Trying samus in ru  Success!
# Attempt #564: Trying leningradskiy in tj  Success!
# Attempt #565: Trying saskylakh in ru  Success!
# Attempt #566: Trying vila franca do campo in pt  Success!
# Attempt #567: Trying barrow in us  Success!
# Attempt #568: Trying bengkulu in id  Success!
# Attempt #569: Trying hermanus in za  Success!
# Attempt #570: Trying castro in cl  Success!
# Attempt #571: Trying carnarvon in au  Success!
# Attempt #572: Trying ostrovnoy in ru  Success!
# Attempt #573: Trying mataura in pf  Success!
# Attempt #574: Trying qaanaaq in gl  Success!
# Attempt #575: Trying kashi in cn  Success!
# Attempt #576: Trying lagoa in pt  Success!
# Attempt #577: Trying ushuaia in ar  Success!
# Attempt #578: Trying saint-philippe in re  Success!
# Attempt #579: Trying severo-kurilsk in ru  Success!
# Attempt #580: Trying porto novo in cv  Success!
# Attempt #581: Trying hofn in is  Success!
# Attempt #582: Trying stryn in no  Success!
# Attempt #583: Trying butte in us  Success!
# Attempt #584: Trying chapais in ca  Success!
# Attempt #585: Trying ambilobe in mg  Success!
# Attempt #586: Trying sorvag in fo  Ouch! Missing field/result... skipping.
# Attempt #587: Trying nikolskoye in ru  Success!
# Attempt #588: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #589: Trying busselton in au  Success!
# Attempt #590: Trying muros in es  Success!
# Attempt #591: Trying hilo in us  Success!
# Attempt #592: Trying klaksvik in fo  Success!
# Attempt #593: Trying qaanaaq in gl  Success!
# Attempt #594: Trying hilo in us  Success!
# Attempt #595: Trying ribeira grande in pt  Success!
# Attempt #596: Trying mansa in zm  Success!
# Attempt #597: Trying karaul in ru  Ouch! Missing field/result... skipping.
# Attempt #598: Trying bredasdorp in za  Success!
# Attempt #599: Trying carnarvon in au  Success!
# Attempt #600: Trying esperance in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 278
# ---------------------------------
# Attempt #601: Trying bengkulu in id  Success!
# Attempt #602: Trying busselton in au  Success!
# Attempt #603: Trying tiznit in ma  Success!
# Attempt #604: Trying cape town in za  Success!
# Attempt #605: Trying tomohon in id  Success!
# Attempt #606: Trying kapaa in us  Success!
# Attempt #607: Trying sept-iles in ca  Success!
# Attempt #608: Trying krasnoselkup in ru  Success!
# Attempt #609: Trying yenagoa in ng  Success!
# Attempt #610: Trying hilo in us  Success!
# Attempt #611: Trying port hardy in ca  Success!
# Attempt #612: Trying turayf in sa  Success!
# Attempt #613: Trying zamora in ec  Success!
# Attempt #614: Trying tilichiki in ru  Success!
# Attempt #615: Trying atkarsk in ru  Success!
# Attempt #616: Trying bara in sd  Success!
# Attempt #617: Trying barcelos in br  Success!
# Attempt #618: Trying klaksvik in fo  Success!
# Attempt #619: Trying tiksi in ru  Success!
# Attempt #620: Trying atuona in pf  Success!
# Attempt #621: Trying mandera in ke  Success!
# Attempt #622: Trying rikitea in pf  Success!
# Attempt #623: Trying busselton in au  Success!
# Attempt #624: Trying poum in nc  Success!
# Attempt #625: Trying durban in za  Success!
# Attempt #626: Trying puerto leguizamo in co  Success!
# Attempt #627: Trying busselton in au  Success!
# Attempt #628: Trying carnarvon in au  Success!
# Attempt #629: Trying jalu in ly  Success!
# Attempt #630: Trying cayenne in gf  Success!
# Attempt #631: Trying barawe in so  Ouch! Missing field/result... skipping.
# Attempt #632: Trying rikitea in pf  Success!
# Attempt #633: Trying acarau in br  Success!
# Attempt #634: Trying cape town in za  Success!
# Attempt #635: Trying port alfred in za  Success!
# Attempt #636: Trying kavaratti in in  Success!
# Attempt #637: Trying svetlyy in ru  Success!
# Attempt #638: Trying albany in au  Success!
# Attempt #639: Trying mahebourg in mu  Success!
# Attempt #640: Trying rikitea in pf  Success!
# Attempt #641: Trying soe in id  Success!
# Attempt #642: Trying busselton in au  Success!
# Attempt #643: Trying jiutai in cn  Success!
# Attempt #644: Trying georgetown in sh  Success!
# Attempt #645: Trying saint-raphael in fr  Success!
# Attempt #646: Trying sosnovo-ozerskoye in ru  Success!
# Attempt #647: Trying port alfred in za  Success!
# Attempt #648: Trying nizhneyansk in ru  Ouch! Missing field/result... skipping.
# Attempt #649: Trying esperance in au  Success!
# Attempt #650: Trying busselton in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 298
# ---------------------------------
# Attempt #651: Trying novoleushkovskaya in ru  Success!
# Attempt #652: Trying arraial do cabo in br  Success!
# Attempt #653: Trying riyadh in sa  Success!
# Attempt #654: Trying tual in id  Success!
# Attempt #655: Trying port blair in in  Success!
# Attempt #656: Trying mount isa in au  Success!
# Attempt #657: Trying pevek in ru  Success!
# Attempt #658: Trying amapa in br  Success!
# Attempt #659: Trying saint-ambroise in ca  Success!
# Attempt #660: Trying bubaque in gw  Success!
# Attempt #661: Trying faya in td  Success!
# Attempt #662: Trying hobart in au  Success!
# Attempt #663: Trying albany in au  Success!
# Attempt #664: Trying hermanus in za  Success!
# Attempt #665: Trying punta arenas in cl  Success!
# Attempt #666: Trying avarua in ck  Success!
# Attempt #667: Trying jamestown in sh  Success!
# Attempt #668: Trying jamestown in sh  Success!
# Attempt #669: Trying buritizeiro in br  Success!
# Attempt #670: Trying mataura in pf  Success!
# Attempt #671: Trying port alfred in za  Success!
# Attempt #672: Trying avarua in ck  Success!
# Attempt #673: Trying mataura in pf  Success!
# Attempt #674: Trying tura in ru  Success!
# Attempt #675: Trying mataura in pf  Success!
# Attempt #676: Trying kirchzarten in de  Success!
# Attempt #677: Trying barrow in us  Success!
# Attempt #678: Trying ribeira grande in pt  Success!
# Attempt #679: Trying kenitra in ma  Success!
# Attempt #680: Trying galeana in mx  Success!
# Attempt #681: Trying coahuayana in mx  Success!
# Attempt #682: Trying bud in no  Success!
# Attempt #683: Trying punta arenas in cl  Success!
# Attempt #684: Trying te anau in nz  Success!
# Attempt #685: Trying kodiak in us  Success!
# Attempt #686: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #687: Trying bengkulu in id  Success!
# Attempt #688: Trying los llanos de aridane in es  Success!
# Attempt #689: Trying galeana in mx  Success!
# Attempt #690: Trying port alfred in za  Success!
# Attempt #691: Trying caxito in ao  Success!
# Attempt #692: Trying jamestown in sh  Success!
# Attempt #693: Trying guaraniacu in br  Success!
# Attempt #694: Trying turka in ua  Success!
# Attempt #695: Trying tasiilaq in gl  Success!
# Attempt #696: Trying victoria in sc  Success!
# Attempt #697: Trying busselton in au  Success!
# Attempt #698: Trying albany in au  Success!
# Attempt #699: Trying port alfred in za  Success!
# Attempt #700: Trying ostrovnoy in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 316
# ---------------------------------
# Attempt #701: Trying ballina in ie  Success!
# Attempt #702: Trying kalemie in cd  Success!
# Attempt #703: Trying vaini in to  Success!
# Attempt #704: Trying tilichiki in ru  Success!
# Attempt #705: Trying vaini in to  Success!
# Attempt #706: Trying jamestown in sh  Success!
# Attempt #707: Trying aquiraz in br  Success!
# Attempt #708: Trying rikitea in pf  Success!
# Attempt #709: Trying muzhi in ru  Success!
# Attempt #710: Trying souillac in mu  Success!
# Attempt #711: Trying itanhem in br  Success!
# Attempt #712: Trying luancheng in cn  Success!
# Attempt #713: Trying kanashevo in ru  Success!
# Attempt #714: Trying pervomayskiy in ru  Success!
# Attempt #715: Trying albany in au  Success!
# Attempt #716: Trying port alfred in za  Success!
# Attempt #717: Trying port elizabeth in za  Success!
# Attempt #718: Trying severo-kurilsk in ru  Success!
# Attempt #719: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #720: Trying rikitea in pf  Success!
# Attempt #721: Trying puerto ayora in ec  Success!
# Attempt #722: Trying qaanaaq in gl  Success!
# Attempt #723: Trying cape town in za  Success!
# Attempt #724: Trying albany in au  Success!
# Attempt #725: Trying rio grande in br  Success!
# Attempt #726: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #727: Trying airai in pw  Success!
# Attempt #728: Trying bagotville in ca  Success!
# Attempt #729: Trying rikitea in pf  Success!
# Attempt #730: Trying baykit in ru  Success!
# Attempt #731: Trying awbari in ly  Success!
# Attempt #732: Trying atuona in pf  Success!
# Attempt #733: Trying abu kamal in sy  Success!
# Attempt #734: Trying thompson in ca  Success!
# Attempt #735: Trying esperance in au  Success!
# Attempt #736: Trying tuktoyaktuk in ca  Success!
# Attempt #737: Trying salalah in om  Success!
# Attempt #738: Trying mocambique in mz  Ouch! Missing field/result... skipping.
# Attempt #739: Trying umzimvubu in za  Ouch! Missing field/result... skipping.
# Attempt #740: Trying mar del plata in ar  Success!
# Attempt #741: Trying tasiilaq in gl  Success!
# Attempt #742: Trying nome in us  Success!
# Attempt #743: Trying chapais in ca  Success!
# Attempt #744: Trying saskylakh in ru  Success!
# Attempt #745: Trying rikitea in pf  Success!
# Attempt #746: Trying jinka in et  Success!
# Attempt #747: Trying dikson in ru  Success!
# Attempt #748: Trying mwinilunga in zm  Success!
# Attempt #749: Trying gazli in uz  Success!
# Attempt #750: Trying lipin bor in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 335
# ---------------------------------
# Attempt #751: Trying new norfolk in au  Success!
# Attempt #752: Trying qorveh in ir  Success!
# Attempt #753: Trying rikitea in pf  Success!
# Attempt #754: Trying ushuaia in ar  Success!
# Attempt #755: Trying rikitea in pf  Success!
# Attempt #756: Trying chifeng in cn  Success!
# Attempt #757: Trying amahai in id  Success!
# Attempt #758: Trying port alfred in za  Success!
# Attempt #759: Trying bambous virieux in mu  Success!
# Attempt #760: Trying mangrol in in  Success!
# Attempt #761: Trying hobart in au  Success!
# Attempt #762: Trying belmonte in br  Success!
# Attempt #763: Trying cumaribo in co  Ouch! Missing field/result... skipping.
# Attempt #764: Trying port keats in au  Success!
# Attempt #765: Trying jalu in ly  Success!
# Attempt #766: Trying saint-augustin in ca  Success!
# Attempt #767: Trying puerto ayora in ec  Success!
# Attempt #768: Trying champerico in gt  Success!
# Attempt #769: Trying thompson in ca  Success!
# Attempt #770: Trying castlemaine in au  Success!
# Attempt #771: Trying djambala in cg  Success!
# Attempt #772: Trying avarua in ck  Success!
# Attempt #773: Trying castro in cl  Success!
# Attempt #774: Trying saint-louis in sn  Success!
# Attempt #775: Trying rantepao in id  Success!
# Attempt #776: Trying aklavik in ca  Success!
# Attempt #777: Trying sinnamary in gf  Success!
# Attempt #778: Trying great falls in us  Success!
# Attempt #779: Trying sambava in mg  Success!
# Attempt #780: Trying mataura in pf  Success!
# Attempt #781: Trying ocos in gt  Success!
# Attempt #782: Trying kambove in cd  Success!
# Attempt #783: Trying barra patuca in hn  Success!
# Attempt #784: Trying lebu in cl  Success!
# Attempt #785: Trying cape town in za  Success!
# Attempt #786: Trying les cayes in ht  Success!
# Attempt #787: Trying ushuaia in ar  Success!
# Attempt #788: Trying cape town in za  Success!
# Attempt #789: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #790: Trying punta arenas in cl  Success!
# Attempt #791: Trying mataura in pf  Success!
# Attempt #792: Trying borba in br  Success!
# Attempt #793: Trying hermanus in za  Success!
# Attempt #794: Trying bengkulu in id  Success!
# Attempt #795: Trying nizhneyansk in ru  Ouch! Missing field/result... skipping.
# Attempt #796: Trying rikitea in pf  Success!
# Attempt #797: Trying georgetown in sh  Success!
# Attempt #798: Trying sao filipe in cv  Success!
# Attempt #799: Trying umzimvubu in za  Ouch! Missing field/result... skipping.
# Attempt #800: Trying high level in ca  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 357
# ---------------------------------
# Attempt #801: Trying busselton in au  Success!
# Attempt #802: Trying ponta do sol in cv  Success!
# Attempt #803: Trying klaksvik in fo  Success!
# Attempt #804: Trying yellowknife in ca  Success!
# Attempt #805: Trying atuona in pf  Success!
# Attempt #806: Trying bandar-e lengeh in ir  Success!
# Attempt #807: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #808: Trying busselton in au  Success!
# Attempt #809: Trying rikitea in pf  Success!
# Attempt #810: Trying saravan in la  Success!
# Attempt #811: Trying punta arenas in cl  Success!
# Attempt #812: Trying gurskoye in ru  Ouch! Missing field/result... skipping.
# Attempt #813: Trying bredasdorp in za  Success!
# Attempt #814: Trying rikitea in pf  Success!
# Attempt #815: Trying ayutla in mx  Success!
# Attempt #816: Trying stornoway in gb  Success!
# Attempt #817: Trying port elizabeth in za  Success!
# Attempt #818: Trying tuktoyaktuk in ca  Success!
# Attempt #819: Trying meyzieu in fr  Success!
# Attempt #820: Trying albany in au  Success!
# Attempt #821: Trying bethel in us  Success!
# Attempt #822: Trying mossendjo in cg  Success!
# Attempt #823: Trying palana in ru  Success!
# Attempt #824: Trying mataura in pf  Success!
# Attempt #825: Trying cherskiy in ru  Success!
# Attempt #826: Trying nishiwaki in jp  Success!
# Attempt #827: Trying rikitea in pf  Success!
# Attempt #828: Trying ancud in cl  Success!
# Attempt #829: Trying albany in au  Success!
# Attempt #830: Trying longyearbyen in sj  Success!
# Attempt #831: Trying la celia in co  Success!
# Attempt #832: Trying sentyabrskiy in ru  Ouch! Missing field/result... skipping.
# Attempt #833: Trying ushuaia in ar  Success!
# Attempt #834: Trying la rioja in ar  Success!
# Attempt #835: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #836: Trying tuktoyaktuk in ca  Success!
# Attempt #837: Trying itarema in br  Success!
# Attempt #838: Trying kapoeta in sd  Success!
# Attempt #839: Trying rikitea in pf  Success!
# Attempt #840: Trying loukhi in ru  Success!
# Attempt #841: Trying hermanus in za  Success!
# Attempt #842: Trying bambous virieux in mu  Success!
# Attempt #843: Trying san patricio in mx  Success!
# Attempt #844: Trying liverpool in ca  Success!
# Attempt #845: Trying lavrentiya in ru  Success!
# Attempt #846: Trying vostok in ru  Success!
# Attempt #847: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #848: Trying hobart in au  Success!
# Attempt #849: Trying nikolskoye in ru  Success!
# Attempt #850: Trying hobart in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 371
# ---------------------------------
# Attempt #851: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #852: Trying punta arenas in cl  Success!
# Attempt #853: Trying shingu in jp  Success!
# Attempt #854: Trying victoria in sc  Success!
# Attempt #855: Trying maragogi in br  Success!
# Attempt #856: Trying cidreira in br  Success!
# Attempt #857: Trying norman wells in ca  Success!
# Attempt #858: Trying vaini in to  Success!
# Attempt #859: Trying amderma in ru  Ouch! Missing field/result... skipping.
# Attempt #860: Trying rikitea in pf  Success!
# Attempt #861: Trying talcahuano in cl  Success!
# Attempt #862: Trying sa kaeo in th  Success!
# Attempt #863: Trying amderma in ru  Ouch! Missing field/result... skipping.
# Attempt #864: Trying hilo in us  Success!
# Attempt #865: Trying torbay in ca  Success!
# Attempt #866: Trying punta arenas in cl  Success!
# Attempt #867: Trying busselton in au  Success!
# Attempt #868: Trying ushuaia in ar  Success!
# Attempt #869: Trying east london in za  Success!
# Attempt #870: Trying orangeburg in us  Success!
# Attempt #871: Trying sitka in us  Success!
# Attempt #872: Trying punta arenas in cl  Success!
# Attempt #873: Trying barrow in us  Success!
# Attempt #874: Trying albany in au  Success!
# Attempt #875: Trying abu samrah in qa  Success!
# Attempt #876: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #877: Trying brokopondo in sr  Success!
# Attempt #878: Trying busselton in au  Success!
# Attempt #879: Trying vao in nc  Success!
# Attempt #880: Trying port alfred in za  Success!
# Attempt #881: Trying hermanus in za  Success!
# Attempt #882: Trying kanashevo in ru  Success!
# Attempt #883: Trying miri in my  Success!
# Attempt #884: Trying borujerd in ir  Success!
# Attempt #885: Trying tuktoyaktuk in ca  Success!
# Attempt #886: Trying naze in jp  Success!
# Attempt #887: Trying nata in bw  Success!
# Attempt #888: Trying mataura in pf  Success!
# Attempt #889: Trying kloulklubed in pw  Success!
# Attempt #890: Trying lasa in cn  Success!
# Attempt #891: Trying hermanus in za  Success!
# Attempt #892: Trying saint-augustin in ca  Success!
# Attempt #893: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #894: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #895: Trying new norfolk in au  Success!
# Attempt #896: Trying columbus in us  Success!
# Attempt #897: Trying iqaluit in ca  Success!
# Attempt #898: Trying atar in mr  Success!
# Attempt #899: Trying cabo san lucas in mx  Success!
# Attempt #900: Trying yinchuan in cn  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 388
# ---------------------------------
# Attempt #901: Trying pozo colorado in py  Success!
# Attempt #902: Trying mataura in pf  Success!
# Attempt #903: Trying margate in za  Success!
# Attempt #904: Trying hobart in au  Success!
# Attempt #905: Trying ushuaia in ar  Success!
# Attempt #906: Trying kudahuvadhoo in mv  Success!
# Attempt #907: Trying kieta in pg  Success!
# Attempt #908: Trying mar del plata in ar  Success!
# Attempt #909: Trying qaanaaq in gl  Success!
# Attempt #910: Trying ushuaia in ar  Success!
# Attempt #911: Trying olafsvik in is  Success!
# Attempt #912: Trying ilulissat in gl  Success!
# Attempt #913: Trying east london in za  Success!
# Attempt #914: Trying yellowknife in ca  Success!
# Attempt #915: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #916: Trying punta arenas in cl  Success!
# Attempt #917: Trying busselton in au  Success!
# Attempt #918: Trying pata in ws  Success!
# Attempt #919: Trying bredasdorp in za  Success!
# Attempt #920: Trying ushuaia in ar  Success!
# Attempt #921: Trying avarua in ck  Success!
# Attempt #922: Trying portland in au  Success!
# Attempt #923: Trying vardo in no  Success!
# Attempt #924: Trying srednekolymsk in ru  Success!
# Attempt #925: Trying galesong in id  Success!
# Attempt #926: Trying new norfolk in au  Success!
# Attempt #927: Trying turiacu in br  Success!
# Attempt #928: Trying mar del plata in ar  Success!
# Attempt #929: Trying ponta do sol in cv  Success!
# Attempt #930: Trying bluff in nz  Success!
# Attempt #931: Trying georgetown in sh  Success!
# Attempt #932: Trying rikitea in pf  Success!
# Attempt #933: Trying busselton in au  Success!
# Attempt #934: Trying orcopampa in pe  Success!
# Attempt #935: Trying albany in au  Success!
# Attempt #936: Trying mackay in au  Success!
# Attempt #937: Trying jamestown in sh  Success!
# Attempt #938: Trying vaini in to  Success!
# Attempt #939: Trying butaritari in ki  Success!
# Attempt #940: Trying egvekinot in ru  Success!
# Attempt #941: Trying ushuaia in ar  Success!
# ...
# Attempt #998: Trying bluff in nz  Success!
# Attempt #999: Trying kamenskoye in ru  Ouch! Missing field/result... skipping.
# Attempt #1000: Trying ituni in gy  Ouch! Missing field/result... skipping.
# ---------------------------------
# Checking for duplicates.....resetting counter: 418
# ---------------------------------
# Attempt #1001: Trying barrow in us  Success!
# Attempt #1002: Trying east london in za  Success!
# Attempt #1003: Trying jamestown in sh  Success!
# Attempt #1004: Trying hilo in us  Success!
# Attempt #1005: Trying terenos in br  Success!
# Attempt #1006: Trying puerto ayora in ec  Success!
# Attempt #1007: Trying cam pha in vn  Ouch! Missing field/result... skipping.
# Attempt #1008: Trying muros in es  Success!
# Attempt #1009: Trying prabumulih in id  Success!
# Attempt #1010: Trying albany in au  Success!
# Attempt #1011: Trying ribeira grande in pt  Success!
# Attempt #1012: Trying mataura in pf  Success!
# Attempt #1013: Trying makakilo city in us  Success!
# Attempt #1014: Trying avarua in ck  Success!
# Attempt #1015: Trying leh in in  Success!
# Attempt #1016: Trying bluff in nz  Success!
# Attempt #1017: Trying klaksvik in fo  Success!
# Attempt #1018: Trying busselton in au  Success!
# Attempt #1019: Trying erenhot in cn  Success!
# Attempt #1020: Trying busselton in au  Success!
# Attempt #1021: Trying victoria in sc  Success!
# Attempt #1022: Trying san ramon in bo  Success!
# Attempt #1023: Trying saint george in bm  Success!
# Attempt #1024: Trying rikitea in pf  Success!
# Attempt #1025: Trying saleaula in ws  Ouch! Missing field/result... skipping.
# Attempt #1026: Trying chicontepec in mx  Success!
# Attempt #1027: Trying busselton in au  Success!
# Attempt #1028: Trying margate in za  Success!
# Attempt #1029: Trying busselton in au  Success!
# Attempt #1030: Trying rikitea in pf  Success!
# Attempt #1031: Trying atuona in pf  Success!
# Attempt #1032: Trying hermanus in za  Success!
# Attempt #1033: Trying stokmarknes in no  Success!
# Attempt #1034: Trying saldanha in za  Success!
# Attempt #1035: Trying pevek in ru  Success!
# Attempt #1036: Trying tuatapere in nz  Success!
# Attempt #1037: Trying saleaula in ws  Ouch! Missing field/result... skipping.
# Attempt #1038: Trying yellowknife in ca  Success!
# Attempt #1039: Trying bengkulu in id  Success!
# Attempt #1040: Trying saskylakh in ru  Success!
# Attempt #1041: Trying mataura in pf  Success!
# Attempt #1042: Trying north bend in us  Success!
# Attempt #1043: Trying husavik in is  Success!
# Attempt #1044: Trying kisesa in tz  Success!
# Attempt #1045: Trying kahului in us  Success!
# Attempt #1046: Trying victoria in sc  Success!
# Attempt #1047: Trying esperance in au  Success!
# Attempt #1048: Trying cape town in za  Success!
# Attempt #1049: Trying kapaa in us  Success!
# Attempt #1050: Trying pevek in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 428
# ---------------------------------
# Attempt #1051: Trying barrow in us  Success!
# Attempt #1052: Trying vaini in to  Success!
# Attempt #1053: Trying yellowknife in ca  Success!
# Attempt #1054: Trying bocicoiu mare in ro  Success!
# Attempt #1055: Trying ushuaia in ar  Success!
# Attempt #1056: Trying cape town in za  Success!
# Attempt #1057: Trying tuktoyaktuk in ca  Success!
# Attempt #1058: Trying bredasdorp in za  Success!
# Attempt #1059: Trying bluff in nz  Success!
# Attempt #1060: Trying omsukchan in ru  Success!
# Attempt #1061: Trying victoria in sc  Success!
# Attempt #1062: Trying punta arenas in cl  Success!
# Attempt #1063: Trying kaitangata in nz  Success!
# Attempt #1064: Trying amapa in br  Success!
# Attempt #1065: Trying muros in es  Success!
# Attempt #1066: Trying yabrud in sy  Success!
# Attempt #1067: Trying san cristobal in ec  Success!
# Attempt #1068: Trying waipawa in nz  Success!
# Attempt #1069: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #1070: Trying provideniya in ru  Success!
# Attempt #1071: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1072: Trying ust-kuyga in ru  Success!
# Attempt #1073: Trying esil in kz  Success!
# Attempt #1074: Trying bluff in nz  Success!
# Attempt #1075: Trying nikolskoye in ru  Success!
# Attempt #1076: Trying ushuaia in ar  Success!
# Attempt #1077: Trying longyearbyen in sj  Success!
# Attempt #1078: Trying storslett in no  Success!
# Attempt #1079: Trying catanduva in br  Success!
# Attempt #1080: Trying ahipara in nz  Success!
# Attempt #1081: Trying saskylakh in ru  Success!
# Attempt #1082: Trying lavrentiya in ru  Success!
# Attempt #1083: Trying punta arenas in cl  Success!
# Attempt #1084: Trying ushuaia in ar  Success!
# Attempt #1085: Trying avarua in ck  Success!
# Attempt #1086: Trying kavaratti in in  Success!
# Attempt #1087: Trying chuy in uy  Success!
# Attempt #1088: Trying rikitea in pf  Success!
# Attempt #1089: Trying lovozero in ru  Success!
# Attempt #1090: Trying shimoda in jp  Success!
# Attempt #1091: Trying busselton in au  Success!
# Attempt #1092: Trying coquimbo in cl  Success!
# Attempt #1093: Trying itarema in br  Success!
# Attempt #1094: Trying new norfolk in au  Success!
# Attempt #1095: Trying san quintin in mx  Success!
# Attempt #1096: Trying geraldton in au  Success!
# Attempt #1097: Trying constitucion in mx  Success!
# Attempt #1098: Trying ushuaia in ar  Success!
# Attempt #1099: Trying ribeira grande in pt  Success!
# Attempt #1100: Trying ust-kamchatsk in ru  Ouch! Missing field/result... skipping.
# ---------------------------------
# Checking for duplicates.....resetting counter: 440
# ---------------------------------
# Attempt #1101: Trying bambous virieux in mu  Success!
# Attempt #1102: Trying busselton in au  Success!
# Attempt #1103: Trying slantsy in ru  Success!
# Attempt #1104: Trying am timan in td  Success!
# Attempt #1105: Trying grand gaube in mu  Success!
# Attempt #1106: Trying alamogordo in us  Success!
# Attempt #1107: Trying resen in mk  Success!
# Attempt #1108: Trying chokurdakh in ru  Success!
# Attempt #1109: Trying husavik in is  Success!
# Attempt #1110: Trying punta arenas in cl  Success!
# Attempt #1111: Trying kruisfontein in za  Success!
# Attempt #1112: Trying hangu in cn  Success!
# Attempt #1113: Trying mataura in pf  Success!
# Attempt #1114: Trying baijiantan in cn  Success!
# Attempt #1115: Trying aasiaat in gl  Success!
# Attempt #1116: Trying rikitea in pf  Success!
# Attempt #1117: Trying hilo in us  Success!
# Attempt #1118: Trying east london in za  Success!
# Attempt #1119: Trying rio gallegos in ar  Success!
# Attempt #1120: Trying hermanus in za  Success!
# Attempt #1121: Trying sharjah in ae  Success!
# Attempt #1122: Trying todos santos in mx  Success!
# Attempt #1123: Trying tiksi in ru  Success!
# Attempt #1124: Trying timmins in ca  Success!
# Attempt #1125: Trying hermanus in za  Success!
# Attempt #1126: Trying ushuaia in ar  Success!
# Attempt #1127: Trying buin in pg  Success!
# Attempt #1128: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1129: Trying jamestown in sh  Success!
# Attempt #1130: Trying ushuaia in ar  Success!
# Attempt #1131: Trying cape town in za  Success!
# Attempt #1132: Trying kodiak in us  Success!
# Attempt #1133: Trying twin falls in us  Success!
# Attempt #1134: Trying whitehorse in ca  Success!
# Attempt #1135: Trying mozarlandia in br  Success!
# Attempt #1136: Trying punta arenas in cl  Success!
# Attempt #1137: Trying san patricio in mx  Success!
# Attempt #1138: Trying naranjal in py  Success!
# Attempt #1139: Trying ratnagiri in in  Success!
# Attempt #1140: Trying iqaluit in ca  Success!
# Attempt #1141: Trying georgetown in sh  Success!
# Attempt #1142: Trying mataura in pf  Success!
# Attempt #1143: Trying new norfolk in au  Success!
# Attempt #1144: Trying tiksi in ru  Success!
# Attempt #1145: Trying mokhotlong in ls  Success!
# Attempt #1146: Trying kaputa in zm  Success!
# Attempt #1147: Trying panvel in in  Success!
# Attempt #1148: Trying prince rupert in ca  Success!
# Attempt #1149: Trying chuy in uy  Success!
# Attempt #1150: Trying saint-philippe in re  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 460
# ---------------------------------
# Attempt #1151: Trying hermanus in za  Success!
# Attempt #1152: Trying peace river in ca  Success!
# Attempt #1153: Trying mataura in pf  Success!
# Attempt #1154: Trying albany in au  Success!
# Attempt #1155: Trying sabha in ly  Success!
# Attempt #1156: Trying rikitea in pf  Success!
# Attempt #1157: Trying shimanovsk in ru  Success!
# Attempt #1158: Trying mirnyy in ru  Success!
# Attempt #1159: Trying lolua in tv  Ouch! Missing field/result... skipping.
# Attempt #1160: Trying myitkyina in mm  Success!
# Attempt #1161: Trying ribeira grande in pt  Success!
# Attempt #1162: Trying tripoli in ly  Success!
# Attempt #1163: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #1164: Trying mrirt in ma  Ouch! Missing field/result... skipping.
# Attempt #1165: Trying parkes in au  Success!
# Attempt #1166: Trying east london in za  Success!
# Attempt #1167: Trying samusu in ws  Ouch! Missing field/result... skipping.
# Attempt #1168: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1169: Trying albany in au  Success!
# Attempt #1170: Trying narsaq in gl  Success!
# Attempt #1171: Trying kibuye in rw  Success!
# Attempt #1172: Trying cilegon in id  Success!
# Attempt #1173: Trying kwekwe in zw  Success!
# Attempt #1174: Trying rikitea in pf  Success!
# Attempt #1175: Trying sault sainte marie in ca  Success!
# Attempt #1176: Trying khandyga in ru  Success!
# Attempt #1177: Trying hithadhoo in mv  Success!
# Attempt #1178: Trying palabuhanratu in id  Ouch! Missing field/result... skipping.
# Attempt #1179: Trying kapaa in us  Success!
# Attempt #1180: Trying isangel in vu  Success!
# Attempt #1181: Trying saint-paul in re  Success!
# Attempt #1182: Trying atherton in au  Success!
# Attempt #1183: Trying hermanus in za  Success!
# Attempt #1184: Trying bredasdorp in za  Success!
# Attempt #1185: Trying camacha in pt  Success!
# Attempt #1186: Trying zavyalovo in ru  Success!
# Attempt #1187: Trying punta arenas in cl  Success!
# Attempt #1188: Trying avarua in ck  Success!
# Attempt #1189: Trying ushuaia in ar  Success!
# Attempt #1190: Trying vaini in to  Success!
# Attempt #1191: Trying bluff in nz  Success!
# Attempt #1192: Trying ponta do sol in cv  Success!
# Attempt #1193: Trying busselton in au  Success!
# Attempt #1194: Trying cidreira in br  Success!
# Attempt #1195: Trying ribeira grande in pt  Success!
# Attempt #1196: Trying qaanaaq in gl  Success!
# Attempt #1197: Trying poya in nc  Success!
# Attempt #1198: Trying lalpur in in  Success!
# Attempt #1199: Trying severo-kurilsk in ru  Success!
# Attempt #1200: Trying ust-uda in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 477
# ---------------------------------
# Attempt #1201: Trying storforshei in no  Success!
# Attempt #1202: Trying kapaa in us  Success!
# Attempt #1203: Trying cockburn town in tc  Success!
# Attempt #1204: Trying punta arenas in cl  Success!
# Attempt #1205: Trying hermanus in za  Success!
# Attempt #1206: Trying punta arenas in cl  Success!
# Attempt #1207: Trying georgetown in sh  Success!
# Attempt #1208: Trying high level in ca  Success!
# Attempt #1209: Trying arraial do cabo in br  Success!
# Attempt #1210: Trying port alfred in za  Success!
# Attempt #1211: Trying ponta do sol in cv  Success!
# Attempt #1212: Trying bambous virieux in mu  Success!
# Attempt #1213: Trying kaitangata in nz  Success!
# Attempt #1214: Trying albany in au  Success!
# Attempt #1215: Trying alofi in nu  Success!
# Attempt #1216: Trying rikitea in pf  Success!
# Attempt #1217: Trying victoria in sc  Success!
# Attempt #1218: Trying labutta in mm  Ouch! Missing field/result... skipping.
# Attempt #1219: Trying luanda in ao  Success!
# Attempt #1220: Trying new norfolk in au  Success!
# Attempt #1221: Trying alofi in nu  Success!
# Attempt #1222: Trying mataura in pf  Success!
# Attempt #1223: Trying shihezi in cn  Success!
# Attempt #1224: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #1225: Trying bluff in nz  Success!
# Attempt #1226: Trying santiago del estero in ar  Success!
# Attempt #1227: Trying thompson in ca  Success!
# Attempt #1228: Trying hami in cn  Success!
# Attempt #1229: Trying mahebourg in mu  Success!
# Attempt #1230: Trying broome in au  Success!
# Attempt #1231: Trying cape town in za  Success!
# Attempt #1232: Trying vaini in to  Success!
# Attempt #1233: Trying broome in au  Success!
# Attempt #1234: Trying salekhard in ru  Success!
# Attempt #1235: Trying kodiak in us  Success!
# Attempt #1236: Trying provideniya in ru  Success!
# Attempt #1237: Trying bluff in nz  Success!
# Attempt #1238: Trying suntar in ru  Success!
# Attempt #1239: Trying vaini in to  Success!
# Attempt #1240: Trying bluff in nz  Success!
# Attempt #1241: Trying lianzhou in cn  Success!
# Attempt #1242: Trying saint-philippe in re  Success!
# Attempt #1243: Trying te anau in nz  Success!
# Attempt #1244: Trying ushuaia in ar  Success!
# Attempt #1245: Trying cururupu in br  Success!
# Attempt #1246: Trying castro in cl  Success!
# Attempt #1247: Trying punta arenas in cl  Success!
# Attempt #1248: Trying kodiak in us  Success!
# Attempt #1249: Trying kapaa in us  Success!
# Attempt #1250: Trying lady lake in us  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 489
# ---------------------------------
# Attempt #1251: Trying mataura in pf  Success!
# Attempt #1252: Trying pacific grove in us  Success!
# Attempt #1253: Trying shimoda in jp  Success!
# Attempt #1254: Trying bluff in nz  Success!
# Attempt #1255: Trying sisimiut in gl  Success!
# Attempt #1256: Trying mecca in sa  Success!
# Attempt #1257: Trying rikitea in pf  Success!
# Attempt #1258: Trying roebourne in au  Success!
# Attempt #1259: Trying sola in vu  Success!
# Attempt #1260: Trying hobart in au  Success!
# Attempt #1261: Trying puerto ayora in ec  Success!
# Attempt #1262: Trying puerto ayora in ec  Success!
# Attempt #1263: Trying simpang in id  Success!
# Attempt #1264: Trying bluff in nz  Success!
# Attempt #1265: Trying busselton in au  Success!
# Attempt #1266: Trying rikitea in pf  Success!
# Attempt #1267: Trying ishigaki in jp  Success!
# Attempt #1268: Trying jamestown in sh  Success!
# Attempt #1269: Trying rikitea in pf  Success!
# Attempt #1270: Trying elko in us  Success!
# Attempt #1271: Trying kruisfontein in za  Success!
# Attempt #1272: Trying saint george in bm  Success!
# Attempt #1273: Trying dondo in mz  Success!
# Attempt #1274: Trying mataura in pf  Success!
# Attempt #1275: Trying la celia in co  Success!
# Attempt #1276: Trying port lincoln in au  Success!
# Attempt #1277: Trying huarmey in pe  Success!
# Attempt #1278: Trying yakshur-bodya in ru  Ouch! Missing field/result... skipping.
# Attempt #1279: Trying saint-philippe in re  Success!
# Attempt #1280: Trying urucara in br  Success!
# Attempt #1281: Trying bambous virieux in mu  Success!
# Attempt #1282: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #1283: Trying tuban in id  Success!
# Attempt #1284: Trying luderitz in na  Success!
# Attempt #1285: Trying jamestown in sh  Success!
# Attempt #1286: Trying lebu in cl  Success!
# Attempt #1287: Trying svobodnyy in ru  Success!
# Attempt #1288: Trying rikitea in pf  Success!
# Attempt #1289: Trying sao joao da ponte in br  Success!
# Attempt #1290: Trying ushuaia in ar  Success!
# Attempt #1291: Trying iskateley in ru  Success!
# Attempt #1292: Trying port alfred in za  Success!
# Attempt #1293: Trying bac lieu in vn  Success!
# Attempt #1294: Trying rikitea in pf  Success!
# Attempt #1295: Trying jamestown in sh  Success!
# Attempt #1296: Trying tuktoyaktuk in ca  Success!
# Attempt #1297: Trying nabire in id  Success!
# Attempt #1298: Trying lososina in ru  Success!
# Attempt #1299: Trying punta arenas in cl  Success!
# Attempt #1300: Trying jamestown in sh  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 504
# ---------------------------------
# ----------------------------------------------
# End of run summary statistics
# Total records: 504
# Number of requests returning no results: 89
# Number of duplicates removed: 708

# %%
# Check results
df_weather_data
# Out:
#                    City Country_Code Input_Lat Input_Lon Actual_Lat  \
# 0                 rundu           NA       -17        20   -17.9333
# 1               ushuaia           AR       -81       -82      -54.8
# 2                  chuy           UY       -49       -37   -33.6971
# 3                 pevek           RU        83       172    69.7008
# 4                mogzon           RU        52       112    51.7435
# ...                 ...          ...       ...       ...        ...
# 1283              tuban           ID        -7       112    -6.8976
# 1287          svobodnyy           RU        52       129       51.4
# 1289  sao joao da ponte           BR       -16       -44   -15.9292
# 1293           bac lieu           VN         7       106      9.285
# 1298           lososina           RU        49       141    48.9975
#
#      Actual_Lon MaxTemp Humidity Cloudiness Wind_Speed             Date_Time
# 0       19.7667   57.94       27         11       4.74   6/16/2021 - 14:31:7
# 1         -68.3   40.62       87          0       3.44   6/16/2021 - 14:31:8
# 2      -53.4616   51.49       68        100      10.69   6/16/2021 - 14:31:8
# 3       170.313   32.27       95         96       7.11   6/16/2021 - 14:31:8
# 4       111.961   41.86       95        100       7.49   6/16/2021 - 14:31:9
# ...         ...     ...      ...        ...        ...                   ...
# 1283    112.065   77.07       85         84        6.2  6/16/2021 - 14:33:13
# 1287    128.133   63.95       97        100       8.81  6/16/2021 - 14:34:50
# 1289   -44.0078   81.09       32         50       4.76  6/16/2021 - 14:34:51
# 1293    105.724   80.91       83         99       6.17  6/16/2021 - 14:34:51
# 1298    140.311   51.48       94         25       5.53  6/16/2021 - 14:34:52
#
# [504 rows x 11 columns]

# %%
# Add "Hemisphere" column
df_weather_data["Hemisphere"] = ""
for index, row in df_weather_data.iterrows():   
    if df_weather_data.loc[index,"Actual_Lat"]>0:
        df_weather_data.loc[index, "Hemisphere"] = "Northern"
    else:
        df_weather_data.loc[index, "Hemisphere"] = "Southern" 
# Save results as csv file

df_weather_data.to_csv("../output_data/cities_2.csv")

# %%
City_ID = np.arange(504)
df_weather_data['City_ID'] = City_ID
df_weather_data_2 = df_weather_data[['City','Actual_Lat','Actual_Lon', 'Date_Time', 'MaxTemp',
                                     'Humidity', 'Cloudiness', 'Wind_Speed']]

# %%
df_weather_data_3 = df_weather_data_2.reset_index()
# df_weather_data_2.drop(columns=["Index"])
df_weather_data_3.drop(['index'],axis=1, inplace=True)
df_weather_data_3.index.rename ('City_ID', inplace=True)
df_weather_data_3.to_html("../Output_for_Web_Page/data-table.html")

# %%
# Are you getting coverage of the full gamut of latitudes? 
fig1, axes = plt.subplots(2,1,sharex=True, sharey=True)
axes[0].hist(lat[:x].astype(float), bins = 50, range = (-90,90), facecolor='r', alpha=0.5)
axes[1].hist(df_weather_data["Actual_Lat"].astype(float), bins = 50, range = (-90,90),facecolor='g', alpha=0.75)
axes[1].set(xlabel = "Latitude")
axes[0].set(ylabel = "Frequency")
axes[1].set(ylabel = "Frequency")
axes[0].set(title = "Latitude <Requests>")
axes[1].set(title = "Latitude <Returns>")
fig1.suptitle('Coverage of latitudes ', fontsize=12)
print("Conclusion:")
print("1. Random lat,long generator produces as a uniform distribution of latitude <Requests>")
print("2. <Returns> can only be generated where cities are. This suggests no cities above 80' N (Artic Circle) and") 
print("below -60' S (Antarctica) which seems reasonable.")
plt.show()
# Are you getting coverage of the full gamut of longitudes? 
fig2, axes = plt.subplots(2,1,sharex=True, sharey=True)
axes[0].hist(lon[:x].astype(float), bins = 50, range = (-180,180), facecolor='r', alpha=0.5)
axes[1].hist(df_weather_data["Actual_Lon"].astype(float), bins = 50, range = (-180,180),facecolor='g', alpha=0.75)
axes[1].set(xlabel = "Longitude")
axes[0].set(ylabel = "Frequency")
axes[1].set(ylabel = "Frequency")
axes[0].set(title = "Longitude <Requests>")
axes[1].set(title = "Longitude <Returns>")
fig2.suptitle('Coverage of longitudes ', fontsize=12)
print("Conclusion:")
print("1. Random lat,long generator produces a uniform distribution of longitude <Requests>")
print("2. <Returns> can only be generated where cities are. This suggests cities are distributed across all longitudes")
print("with concentrations in certain areas (e.g. Europe, North America, SE Asia)")
plt.show()
print("----------------------------------------------------------------------------------------------")
print("Overall conclusion: Random lat,long generator produced random and well distributed data points")
print("----------------------------------------------------------------------------------------------")
fig1.savefig('../Images/LatHist.png')
fig2.savefig('../Images/LongHist.png')
# Out:
# Conclusion:
# 1. Random lat,long generator produces as a uniform distribution of latitude <Requests>
# 2. <Returns> can only be generated where cities are. This suggests no cities above 80' N (Artic Circle) and
# below -60' S (Antarctica) which seems reasonable.
# Conclusion:
# 1. Random lat,long generator produces a uniform distribution of longitude <Requests>
# 2. <Returns> can only be generated where cities are. This suggests cities are distributed across all longitudes
# with concentrations in certain areas (e.g. Europe, North America, SE Asia)
# ----------------------------------------------------------------------------------------------
# Overall conclusion: Random lat,long generator produced random and well distributed data points
# ----------------------------------------------------------------------------------------------

# %%
# Your first requirement is to create a series of scatter plots to showcase the following relationships:

# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
# After each plot add a sentence or too explaining what the code is and analyzing.


scatter_list = ["MaxTemp","Humidity","Cloudiness","Wind_Speed"]
comments = {"MaxTemp":"Looking at relationship/correlation between Temp (F) and Latitude", 
            "Humidity":"Looking at relationship/correlation between Humidity and Latitude",
           "Cloudiness":"Looking at relationship/correlation between Cloudiness(%) and Latitude",
           "Wind_Speed":"Looking at relationship/correlation between Wind Speed (mph) and Latitude"}

for scatter in scatter_list:
    # fig, axes
    y_values = df_weather_data[scatter].astype(float)
    x_values = df_weather_data["Actual_Lat"].astype(float)
    plt.ylabel(scatter)
    plt.title(f'City Latitude versus {scatter}', fontsize=8)
    plt.scatter(x_values,y_values,marker="o", facecolors="green", edgecolors="black", s=10, alpha=0.75)
    plt.xlabel('Latitude')
    plt.grid()
#    plt.figure(figsize=(6.4,4.8)) 
#     print(scatter)
#     print(comments[scatter])
    filename = f"Scatter_Plot_{scatter}.png"
    path = f"../Output_for_Web_Page/{filename}"
    plt.savefig(path)
    plt.show()

# %%
# Your second requirement is to run linear regression on each relationship, only this time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):

# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude

# After each pair of plots explain what the linear regression is modeling such as any relationships you notice and any other analysis you may have.


plot_variables = ["MaxTemp","Humidity","Cloudiness","Wind_Speed"]
hemispheres = ["Northern","Southern"]
comments = {"MaxTemp": "Both  hemispheres show correlations of Temp reducing with distance from equator. Two points of interest: the models predict different temperatures at the equator (y-intercept) and have different slopes",
           "Humidity":"No correlation", "Cloudiness": "No correlation", "Wind_Speed": "No correlation"}
           

for Variable in plot_variables:
    for Hemisphere in hemispheres:
        x_values = df_weather_data.loc[lambda x: x.Hemisphere == Hemisphere]["Actual_Lat"].astype(float)
        y_values = df_weather_data.loc[lambda x: x.Hemisphere == Hemisphere][Variable].astype(float)
        (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
        regress_values = x_values * slope + intercept
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        plt.scatter(x_values,y_values,marker="o", facecolors="red", edgecolors="black", s=10, alpha=0.75)
        plt.plot(x_values,regress_values,"r-")
        # ann_x = x_values.median(); ann_y = y_values.median()
        # plt.annotate(line_eq,(ann_x,ann_y),fontsize=12,color="red")
        plt.xlabel('Latitude')
        plt.ylabel(Variable)
        plt.title(f"{Variable} versus Latitude in the {Hemisphere} hemisphere")
        print(f"The r-squared is: {round(rvalue**2,3)}")
        print(line_eq)
        filename = f"Regression_{Variable}_verus_Latitude_in_{Hemisphere}_hemisphere.png"
        path = f"../Images/ + {filename}"
        plt.savefig(path)
        plt.show()
    print(comments[Variable])
# Out:
# The r-squared is: 0.763
# y = -0.99x + 98.0
# The r-squared is: 0.594
# y = 0.65x + 84.48
# Both  hemispheres show correlations of Temp reducing with distance from equator. Two points of interest: the models predict different temperatures at the equator (y-intercept) and have different slopes
# The r-squared is: 0.043
# y = 0.25x + 55.21
# The r-squared is: 0.021
# y = 0.19x + 75.36
# No correlation
# The r-squared is: 0.03
# y = 0.32x + 45.31
# The r-squared is: 0.104
# y = 0.95x + 71.3
# No correlation
# The r-squared is: 0.009
# y = 0.03x + 7.34
# The r-squared is: 0.0
# y = -0.01x + 7.1
# No correlation

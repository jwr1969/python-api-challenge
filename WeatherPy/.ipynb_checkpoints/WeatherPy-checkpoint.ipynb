# %%
# Create a city list based on random coordinates. Dict or DataFrame? Name, Country, lat, long, Found
# List needs to be very long as we'd expect weather not to find all cities in [OpenWeatherMap API](https://openweathermap.org/api)
# Query open weather map and get Temperature (F), Humidity (%) vs. Latitude, Cloudiness (%), Wind Speed (mph)
# Check coordinates to ensure we got the right city

# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
from scipy import stats
import datetime
from scipy.stats import linregress
from api_keys import weather_api_key

# %%
# Create a DataFrame to hold the data
df_weather_data = pd.DataFrame(index=[0])
df_weather_data["City"] = ""
df_weather_data["Country_Code"] = ""
df_weather_data["Input_Lat"] = ""
df_weather_data["Input_Lon"] = ""
df_weather_data["Actual_Lat"] = ""
df_weather_data["Actual_Lon"] = ""
df_weather_data["MaxTemp"] = ""
df_weather_data["Humidity"] = ""
df_weather_data["Cloudiness"] = ""
df_weather_data["Wind_Speed"] = ""
df_weather_data["Date_Time"] = ""

# %%
# Create a city list based on random coordinates
# Create random coordinates - more than 500 in case of "failures"
lat = np.random.randint(low=-90, high=90, size=2000)
lon = np.random.randint(low=-180, high=180, size=2000)
# Weather url
url = "http://api.openweathermap.org/data/2.5/weather?"
# Find nearest cities
# for x in range(len(lat)):
x = 0
a = 0
skipped = 0
while a < 500:
    city = citipy.nearest_city(lat[x],lon[x])
    city_name = city.city_name
    city_country = city.country_code
    
    # Build query url
    query_url = url + "appid=" + weather_api_key + "&q=" + city_name + "&units=imperial"
    
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    print(f"Attempt #{x}: Trying {city_name} in {city_country}  ", end = "")
    
    try:  
    
        df_weather_data.loc[x,"Actual_Lat"] = weather_json["coord"]["lat"]
        df_weather_data.loc[x,"Actual_Lon"] = weather_json["coord"]["lon"]
        df_weather_data.loc[x,"MaxTemp"] = weather_json["main"]["temp_max"]
        df_weather_data.loc[x,"Humidity"] = weather_json["main"]["humidity"]
        df_weather_data.loc[x,"Cloudiness"] = weather_json["clouds"]["all"]
        df_weather_data.loc[x,"Wind_Speed"] = weather_json["wind"]["speed"]
        
        my_timestamp = weather_json["dt"]
        my_dt = datetime.datetime.fromtimestamp(my_timestamp)       
        date_time = f"{my_dt.month}/{my_dt.day}/{my_dt.year} - {my_dt.hour}:{my_dt.minute}:{my_dt.second}"
  
        df_weather_data.loc[x,"Date_Time"] = date_time
        
        df_weather_data.loc[x,"City"] = city_name
        df_weather_data.loc[x,"Country_Code"] = weather_json["sys"]["country"]
        df_weather_data.loc[x,"Input_Lat"] = lat[x]
        df_weather_data.loc[x,"Input_Lon"] = lon[x]
        
        print(f"Success!")
        
       
    
    except (KeyError):
        
        skipped +=1
        print("Ouch! Missing field/result... skipping.")
        if x == 0:
            x = -1
        else:
            pass
    
    if (x > 10) & (x % 50 == 0):
        df_weather_data.drop_duplicates(subset=["City","Actual_Lat","Actual_Lon"], inplace=True)
        a = df_weather_data["City"].count()
        print("---------------------------------")
        print(f"Checking for duplicates.....resetting counter: {a}")
        print("---------------------------------")
        
        
    
    x +=1
    

    
print("----------------------------------------------")
print("End of run summary statistics")
print(f"Total records: {a}")
print(f"Number of requests returning no results: {skipped}")
print(f"Number of duplicates removed: {((x-skipped))-a}")
# Out:
# Attempt #0: Trying hobart in au  Success!
# Attempt #1: Trying albany in au  Success!
# Attempt #2: Trying esperance in au  Success!
# Attempt #3: Trying dikson in ru  Success!
# Attempt #4: Trying tsihombe in mg  Ouch! Missing field/result... skipping.
# Attempt #5: Trying hilo in us  Success!
# Attempt #6: Trying pisco in pe  Success!
# Attempt #7: Trying hambantota in lk  Success!
# Attempt #8: Trying nizhneyansk in ru  Ouch! Missing field/result... skipping.
# Attempt #9: Trying rikitea in pf  Success!
# Attempt #10: Trying kahului in us  Success!
# Attempt #11: Trying biggar in ca  Success!
# Attempt #12: Trying abu samrah in qa  Success!
# Attempt #13: Trying esperance in au  Success!
# Attempt #14: Trying hobart in au  Success!
# Attempt #15: Trying san cristobal in ec  Success!
# Attempt #16: Trying ishigaki in jp  Success!
# Attempt #17: Trying khatanga in ru  Success!
# Attempt #18: Trying vaini in to  Success!
# Attempt #19: Trying verkhoyansk in ru  Success!
# Attempt #20: Trying spornoye in ru  Success!
# Attempt #21: Trying vilhena in br  Success!
# Attempt #22: Trying kapaa in us  Success!
# Attempt #23: Trying samarai in pg  Success!
# Attempt #24: Trying tiksi in ru  Success!
# Attempt #25: Trying klaksvik in fo  Success!
# Attempt #26: Trying hobart in au  Success!
# Attempt #27: Trying seoul in kr  Success!
# Attempt #28: Trying carnarvon in au  Success!
# Attempt #29: Trying qaanaaq in gl  Success!
# Attempt #30: Trying new norfolk in au  Success!
# Attempt #31: Trying sentyabrskiy in ru  Ouch! Missing field/result... skipping.
# Attempt #32: Trying saint-andre-avellin in ca  Success!
# Attempt #33: Trying thompson in ca  Success!
# Attempt #34: Trying kavaratti in in  Success!
# Attempt #35: Trying alappuzha in in  Success!
# Attempt #36: Trying hermanus in za  Success!
# Attempt #37: Trying hermanus in za  Success!
# Attempt #38: Trying avarua in ck  Success!
# Attempt #39: Trying mahebourg in mu  Success!
# Attempt #40: Trying mar del plata in ar  Success!
# Attempt #41: Trying busselton in au  Success!
# Attempt #42: Trying busselton in au  Success!
# Attempt #43: Trying cherskiy in ru  Success!
# Attempt #44: Trying hilo in us  Success!
# Attempt #45: Trying new norfolk in au  Success!
# Attempt #46: Trying vaini in to  Success!
# Attempt #47: Trying hithadhoo in mv  Success!
# Attempt #48: Trying shenjiamen in cn  Success!
# Attempt #49: Trying albany in au  Success!
# Attempt #50: Trying igarka in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 39
# ---------------------------------
# Attempt #51: Trying albany in au  Success!
# Attempt #52: Trying punta arenas in cl  Success!
# Attempt #53: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #54: Trying bredasdorp in za  Success!
# Attempt #55: Trying pullampadi in in  Ouch! Missing field/result... skipping.
# Attempt #56: Trying alofi in nu  Success!
# Attempt #57: Trying rikitea in pf  Success!
# Attempt #58: Trying norman wells in ca  Success!
# Attempt #59: Trying bambous virieux in mu  Success!
# Attempt #60: Trying vaini in to  Success!
# Attempt #61: Trying dikson in ru  Success!
# Attempt #62: Trying brae in gb  Success!
# Attempt #63: Trying sao joao da barra in br  Success!
# Attempt #64: Trying bluff in nz  Success!
# Attempt #65: Trying kysyl-syr in ru  Success!
# Attempt #66: Trying severo-kurilsk in ru  Success!
# Attempt #67: Trying yeppoon in au  Success!
# Attempt #68: Trying codrington in ag  Success!
# Attempt #69: Trying oksfjord in no  Success!
# Attempt #70: Trying luganville in vu  Success!
# Attempt #71: Trying bluff in nz  Success!
# Attempt #72: Trying georgetown in sh  Success!
# Attempt #73: Trying torbay in ca  Success!
# Attempt #74: Trying viedma in ar  Success!
# Attempt #75: Trying new norfolk in au  Success!
# Attempt #76: Trying thompson in ca  Success!
# Attempt #77: Trying saskylakh in ru  Success!
# Attempt #78: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #79: Trying port lincoln in au  Success!
# Attempt #80: Trying chara in ru  Success!
# Attempt #81: Trying hithadhoo in mv  Success!
# Attempt #82: Trying mahdalynivka in ua  Success!
# Attempt #83: Trying busselton in au  Success!
# Attempt #84: Trying atuona in pf  Success!
# Attempt #85: Trying tuktoyaktuk in ca  Success!
# Attempt #86: Trying fomboni in km  Success!
# Attempt #87: Trying hirara in jp  Success!
# Attempt #88: Trying hermanus in za  Success!
# Attempt #89: Trying thompson in ca  Success!
# Attempt #90: Trying rikitea in pf  Success!
# Attempt #91: Trying ilulissat in gl  Success!
# Attempt #92: Trying khatanga in ru  Success!
# Attempt #93: Trying nanortalik in gl  Success!
# Attempt #94: Trying kodiak in us  Success!
# Attempt #95: Trying yagodnoye in ru  Success!
# Attempt #96: Trying padang in id  Success!
# Attempt #97: Trying kavieng in pg  Success!
# Attempt #98: Trying mataura in pf  Success!
# Attempt #99: Trying esperance in au  Success!
# Attempt #100: Trying waingapu in id  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 72
# ---------------------------------
# Attempt #101: Trying muroto in jp  Success!
# Attempt #102: Trying hithadhoo in mv  Success!
# Attempt #103: Trying mataura in pf  Success!
# Attempt #104: Trying drovyanaya in ru  Success!
# Attempt #105: Trying upernavik in gl  Success!
# Attempt #106: Trying grindavik in is  Success!
# Attempt #107: Trying puerto ayora in ec  Success!
# Attempt #108: Trying souillac in mu  Success!
# Attempt #109: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #110: Trying sentyabrskiy in ru  Ouch! Missing field/result... skipping.
# Attempt #111: Trying attawapiskat in ca  Ouch! Missing field/result... skipping.
# Attempt #112: Trying severo-kurilsk in ru  Success!
# Attempt #113: Trying dubai in ae  Success!
# Attempt #114: Trying jieshou in cn  Success!
# Attempt #115: Trying nueva gerona in cu  Success!
# Attempt #116: Trying kuryk in kz  Success!
# Attempt #117: Trying westport in nz  Success!
# Attempt #118: Trying cidreira in br  Success!
# Attempt #119: Trying kavieng in pg  Success!
# Attempt #120: Trying bredasdorp in za  Success!
# Attempt #121: Trying rikitea in pf  Success!
# Attempt #122: Trying punta arenas in cl  Success!
# Attempt #123: Trying ribeira grande in pt  Success!
# Attempt #124: Trying lodja in cd  Success!
# Attempt #125: Trying punta arenas in cl  Success!
# Attempt #126: Trying rikitea in pf  Success!
# Attempt #127: Trying ponta do sol in cv  Success!
# Attempt #128: Trying adelaide in za  Success!
# Attempt #129: Trying rikitea in pf  Success!
# Attempt #130: Trying srednekolymsk in ru  Success!
# Attempt #131: Trying ushuaia in ar  Success!
# Attempt #132: Trying clyde river in ca  Success!
# Attempt #133: Trying laguna in br  Success!
# Attempt #134: Trying cape town in za  Success!
# Attempt #135: Trying butaritari in ki  Success!
# Attempt #136: Trying busselton in au  Success!
# Attempt #137: Trying kaitangata in nz  Success!
# Attempt #138: Trying margate in za  Success!
# Attempt #139: Trying bluff in nz  Success!
# Attempt #140: Trying hasaki in jp  Success!
# Attempt #141: Trying hoopstad in za  Success!
# Attempt #142: Trying busselton in au  Success!
# Attempt #143: Trying gatbo in ph  Success!
# Attempt #144: Trying albany in au  Success!
# Attempt #145: Trying chokurdakh in ru  Success!
# Attempt #146: Trying mataura in pf  Success!
# Attempt #147: Trying torbay in ca  Success!
# Attempt #148: Trying rikitea in pf  Success!
# Attempt #149: Trying tabou in ci  Success!
# Attempt #150: Trying lompoc in us  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 102
# ---------------------------------
# Attempt #151: Trying saint-philippe in re  Success!
# Attempt #152: Trying salalah in om  Success!
# Attempt #153: Trying port lincoln in au  Success!
# Attempt #154: Trying severo-kurilsk in ru  Success!
# Attempt #155: Trying rock springs in us  Success!
# Attempt #156: Trying jamestown in sh  Success!
# Attempt #157: Trying ushuaia in ar  Success!
# Attempt #158: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #159: Trying hualmay in pe  Success!
# Attempt #160: Trying punta arenas in cl  Success!
# Attempt #161: Trying atar in mr  Success!
# Attempt #162: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #163: Trying bonavista in ca  Success!
# Attempt #164: Trying saint george in bm  Success!
# Attempt #165: Trying ancud in cl  Success!
# Attempt #166: Trying vaini in to  Success!
# Attempt #167: Trying kulhudhuffushi in mv  Success!
# Attempt #168: Trying kapaa in us  Success!
# Attempt #169: Trying rikitea in pf  Success!
# Attempt #170: Trying matay in eg  Success!
# Attempt #171: Trying carnarvon in au  Success!
# Attempt #172: Trying vaini in to  Success!
# Attempt #173: Trying georgetown in sh  Success!
# Attempt #174: Trying yellowknife in ca  Success!
# Attempt #175: Trying ushuaia in ar  Success!
# Attempt #176: Trying venustiano carranza in mx  Success!
# Attempt #177: Trying yellowknife in ca  Success!
# Attempt #178: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #179: Trying mehamn in no  Success!
# Attempt #180: Trying hasaki in jp  Success!
# Attempt #181: Trying manggar in id  Success!
# Attempt #182: Trying castro in cl  Success!
# Attempt #183: Trying guerrero negro in mx  Success!
# Attempt #184: Trying albany in au  Success!
# Attempt #185: Trying weligama in lk  Success!
# Attempt #186: Trying altay in cn  Success!
# Attempt #187: Trying port lincoln in au  Success!
# Attempt #188: Trying tiksi in ru  Success!
# Attempt #189: Trying ilulissat in gl  Success!
# Attempt #190: Trying hobart in au  Success!
# Attempt #191: Trying cidreira in br  Success!
# Attempt #192: Trying san patricio in mx  Success!
# Attempt #193: Trying zachagansk in kz  Ouch! Missing field/result... skipping.
# Attempt #194: Trying hilo in us  Success!
# Attempt #195: Trying huilong in cn  Success!
# Attempt #196: Trying merauke in id  Success!
# Attempt #197: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #198: Trying nikolskoye in ru  Success!
# Attempt #199: Trying kodiak in us  Success!
# Attempt #200: Trying yellowknife in ca  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 125
# ---------------------------------
# Attempt #201: Trying sinnamary in gf  Success!
# Attempt #202: Trying hithadhoo in mv  Success!
# Attempt #203: Trying lebu in cl  Success!
# Attempt #204: Trying vanavara in ru  Success!
# Attempt #205: Trying avarua in ck  Success!
# Attempt #206: Trying mataura in pf  Success!
# Attempt #207: Trying ushuaia in ar  Success!
# Attempt #208: Trying albany in au  Success!
# Attempt #209: Trying ostrovnoy in ru  Success!
# Attempt #210: Trying luderitz in na  Success!
# Attempt #211: Trying puerto ayora in ec  Success!
# Attempt #212: Trying rikitea in pf  Success!
# Attempt #213: Trying dzerzhinsk in by  Success!
# Attempt #214: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #215: Trying new norfolk in au  Success!
# Attempt #216: Trying mataura in pf  Success!
# Attempt #217: Trying victoria in sc  Success!
# Attempt #218: Trying tsuyama in jp  Success!
# Attempt #219: Trying xapuri in br  Success!
# Attempt #220: Trying bluff in nz  Success!
# Attempt #221: Trying pemangkat in id  Success!
# Attempt #222: Trying vaini in to  Success!
# Attempt #223: Trying linhares in br  Success!
# Attempt #224: Trying talnakh in ru  Success!
# Attempt #225: Trying dingle in ie  Success!
# Attempt #226: Trying georgetown in sh  Success!
# Attempt #227: Trying mataura in pf  Success!
# Attempt #228: Trying busselton in au  Success!
# Attempt #229: Trying luderitz in na  Success!
# Attempt #230: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #231: Trying new norfolk in au  Success!
# Attempt #232: Trying mataura in pf  Success!
# Attempt #233: Trying wanning in cn  Success!
# Attempt #234: Trying jamestown in sh  Success!
# Attempt #235: Trying ramshir in ir  Success!
# Attempt #236: Trying slave lake in ca  Success!
# Attempt #237: Trying mataura in pf  Success!
# Attempt #238: Trying inirida in co  Success!
# Attempt #239: Trying havelock in us  Success!
# Attempt #240: Trying hilo in us  Success!
# Attempt #241: Trying te anau in nz  Success!
# Attempt #242: Trying caravelas in br  Success!
# Attempt #243: Trying klaksvik in fo  Success!
# Attempt #244: Trying valparaiso in cl  Success!
# Attempt #245: Trying ushuaia in ar  Success!
# Attempt #246: Trying cherskiy in ru  Success!
# Attempt #247: Trying jamestown in sh  Success!
# Attempt #248: Trying narsaq in gl  Success!
# Attempt #249: Trying punta arenas in cl  Success!
# Attempt #250: Trying busselton in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 147
# ---------------------------------
# Attempt #251: Trying qaanaaq in gl  Success!
# Attempt #252: Trying hilo in us  Success!
# Attempt #253: Trying ushuaia in ar  Success!
# Attempt #254: Trying penzance in gb  Success!
# Attempt #255: Trying lebyazhye in ru  Success!
# Attempt #256: Trying mbale in ug  Success!
# Attempt #257: Trying nisia floresta in br  Success!
# Attempt #258: Trying kavieng in pg  Success!
# Attempt #259: Trying lagoa in pt  Success!
# Attempt #260: Trying qaanaaq in gl  Success!
# Attempt #261: Trying suntar in ru  Success!
# Attempt #262: Trying narsaq in gl  Success!
# Attempt #263: Trying bengkulu in id  Success!
# Attempt #264: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #265: Trying gangotri in in  Ouch! Missing field/result... skipping.
# Attempt #266: Trying rikitea in pf  Success!
# Attempt #267: Trying hithadhoo in mv  Success!
# Attempt #268: Trying nizhniy ufaley in ru  Success!
# Attempt #269: Trying port lincoln in au  Success!
# Attempt #270: Trying chara in ru  Success!
# Attempt #271: Trying kapaa in us  Success!
# Attempt #272: Trying punta arenas in cl  Success!
# Attempt #273: Trying yulara in au  Success!
# Attempt #274: Trying cukai in my  Success!
# Attempt #275: Trying puerto ayora in ec  Success!
# Attempt #276: Trying dikson in ru  Success!
# Attempt #277: Trying amderma in ru  Ouch! Missing field/result... skipping.
# Attempt #278: Trying cowra in au  Success!
# Attempt #279: Trying korla in cn  Success!
# Attempt #280: Trying punta arenas in cl  Success!
# Attempt #281: Trying longyearbyen in sj  Success!
# Attempt #282: Trying punta arenas in cl  Success!
# Attempt #283: Trying ales in fr  Success!
# Attempt #284: Trying bredasdorp in za  Success!
# Attempt #285: Trying busselton in au  Success!
# Attempt #286: Trying dikson in ru  Success!
# Attempt #287: Trying esperance in au  Success!
# Attempt #288: Trying busselton in au  Success!
# Attempt #289: Trying georgetown in sh  Success!
# Attempt #290: Trying ferrol in es  Success!
# Attempt #291: Trying berlevag in no  Success!
# Attempt #292: Trying kapaa in us  Success!
# Attempt #293: Trying east london in za  Success!
# Attempt #294: Trying namatanai in pg  Success!
# Attempt #295: Trying kavaratti in in  Success!
# Attempt #296: Trying caticlan in ph  Success!
# Attempt #297: Trying puerto ayora in ec  Success!
# Attempt #298: Trying hermanus in za  Success!
# Attempt #299: Trying valladolid in es  Success!
# Attempt #300: Trying acajutla in sv  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 168
# ---------------------------------
# Attempt #301: Trying yumen in cn  Success!
# Attempt #302: Trying bredasdorp in za  Success!
# Attempt #303: Trying chokurdakh in ru  Success!
# Attempt #304: Trying fortuna in us  Success!
# Attempt #305: Trying ushuaia in ar  Success!
# Attempt #306: Trying kaitangata in nz  Success!
# Attempt #307: Trying cape town in za  Success!
# Attempt #308: Trying kodiak in us  Success!
# Attempt #309: Trying manokwari in id  Success!
# Attempt #310: Trying tansen in np  Success!
# Attempt #311: Trying butaritari in ki  Success!
# Attempt #312: Trying seymchan in ru  Success!
# Attempt #313: Trying nemuro in jp  Success!
# Attempt #314: Trying inirida in co  Success!
# Attempt #315: Trying punta arenas in cl  Success!
# Attempt #316: Trying hermanus in za  Success!
# Attempt #317: Trying ushuaia in ar  Success!
# Attempt #318: Trying noumea in nc  Success!
# Attempt #319: Trying marawi in sd  Success!
# Attempt #320: Trying vao in nc  Success!
# Attempt #321: Trying yirol in sd  Ouch! Missing field/result... skipping.
# Attempt #322: Trying alta floresta in br  Success!
# Attempt #323: Trying klaksvik in fo  Success!
# Attempt #324: Trying yulara in au  Success!
# Attempt #325: Trying tiksi in ru  Success!
# Attempt #326: Trying albany in au  Success!
# Attempt #327: Trying gat in ly  Success!
# Attempt #328: Trying mataura in pf  Success!
# Attempt #329: Trying saint george in bm  Success!
# Attempt #330: Trying tessalit in ml  Success!
# Attempt #331: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #332: Trying micheweni in tz  Success!
# Attempt #333: Trying ushuaia in ar  Success!
# Attempt #334: Trying bluff in nz  Success!
# Attempt #335: Trying cayenne in gf  Success!
# Attempt #336: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #337: Trying victoria in sc  Success!
# Attempt #338: Trying urambo in tz  Success!
# Attempt #339: Trying astana in kz  Success!
# Attempt #340: Trying karaul in ru  Ouch! Missing field/result... skipping.
# Attempt #341: Trying jiwani in pk  Success!
# Attempt #342: Trying juneau in us  Success!
# Attempt #343: Trying constitucion in mx  Success!
# Attempt #344: Trying champerico in gt  Success!
# Attempt #345: Trying jamestown in sh  Success!
# Attempt #346: Trying sao joao da barra in br  Success!
# Attempt #347: Trying faanui in pf  Success!
# Attempt #348: Trying sitka in us  Success!
# Attempt #349: Trying boa vista in br  Success!
# Attempt #350: Trying busselton in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 191
# ---------------------------------
# Attempt #351: Trying oyama in jp  Success!
# Attempt #352: Trying lagoa in pt  Success!
# Attempt #353: Trying rikitea in pf  Success!
# Attempt #354: Trying bethel in us  Success!
# Attempt #355: Trying mataura in pf  Success!
# Attempt #356: Trying tsihombe in mg  Ouch! Missing field/result... skipping.
# Attempt #357: Trying carnarvon in au  Success!
# Attempt #358: Trying talnakh in ru  Success!
# Attempt #359: Trying kodiak in us  Success!
# Attempt #360: Trying bluff in nz  Success!
# Attempt #361: Trying ust-koksa in ru  Success!
# Attempt #362: Trying fare in pf  Success!
# Attempt #363: Trying hilo in us  Success!
# Attempt #364: Trying ayagoz in kz  Success!
# Attempt #365: Trying ushuaia in ar  Success!
# Attempt #366: Trying kasongo-lunda in cd  Success!
# Attempt #367: Trying aksu in cn  Success!
# Attempt #368: Trying punta arenas in cl  Success!
# Attempt #369: Trying necochea in ar  Success!
# Attempt #370: Trying busselton in au  Success!
# Attempt #371: Trying alofi in nu  Success!
# Attempt #372: Trying port alfred in za  Success!
# Attempt #373: Trying georgetown in sh  Success!
# Attempt #374: Trying punta arenas in cl  Success!
# Attempt #375: Trying lebu in cl  Success!
# Attempt #376: Trying puerto ayora in ec  Success!
# Attempt #377: Trying saint george in bm  Success!
# Attempt #378: Trying berlevag in no  Success!
# Attempt #379: Trying ushuaia in ar  Success!
# Attempt #380: Trying gao in ml  Success!
# Attempt #381: Trying bluff in nz  Success!
# Attempt #382: Trying ribeira grande in pt  Success!
# Attempt #383: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #384: Trying albany in au  Success!
# Attempt #385: Trying beruni in uz  Ouch! Missing field/result... skipping.
# Attempt #386: Trying ushuaia in ar  Success!
# Attempt #387: Trying am timan in td  Success!
# Attempt #388: Trying grand river south east in mu  Ouch! Missing field/result... skipping.
# Attempt #389: Trying tura in ru  Success!
# Attempt #390: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #391: Trying jamestown in sh  Success!
# Attempt #392: Trying kaitangata in nz  Success!
# Attempt #393: Trying kodiak in us  Success!
# Attempt #394: Trying hobart in au  Success!
# Attempt #395: Trying arua in ug  Success!
# Attempt #396: Trying butaritari in ki  Success!
# Attempt #397: Trying boa vista in br  Success!
# Attempt #398: Trying dikson in ru  Success!
# Attempt #399: Trying atuona in pf  Success!
# Attempt #400: Trying bur gabo in so  Ouch! Missing field/result... skipping.
# ---------------------------------
# Checking for duplicates.....resetting counter: 204
# ---------------------------------
# Attempt #401: Trying flinders in au  Success!
# Attempt #402: Trying kununurra in au  Success!
# Attempt #403: Trying anloga in gh  Success!
# Attempt #404: Trying ilulissat in gl  Success!
# Attempt #405: Trying erie in us  Success!
# Attempt #406: Trying staryy nadym in ru  Success!
# Attempt #407: Trying butaritari in ki  Success!
# Attempt #408: Trying narsaq in gl  Success!
# Attempt #409: Trying san patricio in mx  Success!
# Attempt #410: Trying hermanus in za  Success!
# Attempt #411: Trying batangafo in cf  Success!
# Attempt #412: Trying havre in us  Success!
# Attempt #413: Trying freetown in ag  Success!
# Attempt #414: Trying punta arenas in cl  Success!
# Attempt #415: Trying usinsk in ru  Success!
# Attempt #416: Trying barrow in us  Success!
# Attempt #417: Trying toora-khem in ru  Success!
# Attempt #418: Trying price in ca  Success!
# Attempt #419: Trying san patricio in mx  Success!
# Attempt #420: Trying la ronge in ca  Success!
# Attempt #421: Trying tuktoyaktuk in ca  Success!
# Attempt #422: Trying hobart in au  Success!
# Attempt #423: Trying torbay in ca  Success!
# Attempt #424: Trying bethel in us  Success!
# Attempt #425: Trying viligili in mv  Ouch! Missing field/result... skipping.
# Attempt #426: Trying bredasdorp in za  Success!
# Attempt #427: Trying vaini in to  Success!
# Attempt #428: Trying inhambane in mz  Success!
# Attempt #429: Trying aden in ye  Success!
# Attempt #430: Trying grindavik in is  Success!
# Attempt #431: Trying mahadday weyne in so  Ouch! Missing field/result... skipping.
# Attempt #432: Trying estelle in us  Success!
# Attempt #433: Trying hithadhoo in mv  Success!
# Attempt #434: Trying hilo in us  Success!
# Attempt #435: Trying bathsheba in bb  Success!
# Attempt #436: Trying starosubkhangulovo in ru  Success!
# Attempt #437: Trying bredasdorp in za  Success!
# Attempt #438: Trying elko in us  Success!
# Attempt #439: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #440: Trying saskylakh in ru  Success!
# Attempt #441: Trying cape town in za  Success!
# Attempt #442: Trying mataura in pf  Success!
# Attempt #443: Trying nanakuli in us  Success!
# Attempt #444: Trying gat in ly  Success!
# Attempt #445: Trying palabuhanratu in id  Ouch! Missing field/result... skipping.
# Attempt #446: Trying rikitea in pf  Success!
# Attempt #447: Trying jamestown in sh  Success!
# Attempt #448: Trying tasiilaq in gl  Success!
# Attempt #449: Trying rosetta in eg  Success!
# Attempt #450: Trying albany in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 226
# ---------------------------------
# Attempt #451: Trying dudinka in ru  Success!
# Attempt #452: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #453: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #454: Trying airai in pw  Success!
# Attempt #455: Trying albany in au  Success!
# Attempt #456: Trying velingara in sn  Success!
# Attempt #457: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #458: Trying ushuaia in ar  Success!
# Attempt #459: Trying katsuura in jp  Success!
# Attempt #460: Trying mrirt in ma  Ouch! Missing field/result... skipping.
# Attempt #461: Trying hithadhoo in mv  Success!
# Attempt #462: Trying pangnirtung in ca  Success!
# Attempt #463: Trying kango in ga  Success!
# Attempt #464: Trying nizhneyansk in ru  Ouch! Missing field/result... skipping.
# Attempt #465: Trying kristinehamn in se  Success!
# Attempt #466: Trying ushuaia in ar  Success!
# Attempt #467: Trying bredasdorp in za  Success!
# Attempt #468: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #469: Trying willowmore in za  Success!
# Attempt #470: Trying vaini in to  Success!
# Attempt #471: Trying port macquarie in au  Success!
# Attempt #472: Trying shenjiamen in cn  Success!
# Attempt #473: Trying guerrero negro in mx  Success!
# Attempt #474: Trying port hardy in ca  Success!
# Attempt #475: Trying gornoye loo in ru  Success!
# Attempt #476: Trying busselton in au  Success!
# Attempt #477: Trying arraial do cabo in br  Success!
# Attempt #478: Trying luena in ao  Success!
# Attempt #479: Trying ushuaia in ar  Success!
# Attempt #480: Trying arraial do cabo in br  Success!
# Attempt #481: Trying fez in ma  Success!
# Attempt #482: Trying mgandu in tz  Success!
# Attempt #483: Trying goure in ne  Success!
# Attempt #484: Trying puerto baquerizo moreno in ec  Success!
# Attempt #485: Trying coxim in br  Success!
# Attempt #486: Trying grand gaube in mu  Success!
# Attempt #487: Trying ushuaia in ar  Success!
# Attempt #488: Trying qaanaaq in gl  Success!
# Attempt #489: Trying busselton in au  Success!
# Attempt #490: Trying new norfolk in au  Success!
# Attempt #491: Trying mahebourg in mu  Success!
# Attempt #492: Trying clyde river in ca  Success!
# Attempt #493: Trying zerbst in de  Success!
# Attempt #494: Trying alcudia in es  Success!
# Attempt #495: Trying torbay in ca  Success!
# Attempt #496: Trying faanui in pf  Success!
# Attempt #497: Trying dali in cn  Success!
# Attempt #498: Trying tuktoyaktuk in ca  Success!
# Attempt #499: Trying rikitea in pf  Success!
# Attempt #500: Trying albany in au  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 248
# ---------------------------------
# Attempt #501: Trying sentyabrskiy in ru  Ouch! Missing field/result... skipping.
# Attempt #502: Trying innisfail in au  Success!
# Attempt #503: Trying cidreira in br  Success!
# Attempt #504: Trying san juan in us  Success!
# Attempt #505: Trying albany in au  Success!
# Attempt #506: Trying cap malheureux in mu  Success!
# Attempt #507: Trying tiznit in ma  Success!
# Attempt #508: Trying sholavandan in in  Ouch! Missing field/result... skipping.
# Attempt #509: Trying kieta in pg  Success!
# Attempt #510: Trying puerto escondido in mx  Success!
# Attempt #511: Trying severo-kurilsk in ru  Success!
# Attempt #512: Trying kununurra in au  Success!
# Attempt #513: Trying kodiak in us  Success!
# Attempt #514: Trying san cristobal in ec  Success!
# Attempt #515: Trying bengkulu in id  Success!
# Attempt #516: Trying nyurba in ru  Success!
# Attempt #517: Trying punta arenas in cl  Success!
# Attempt #518: Trying punta arenas in cl  Success!
# Attempt #519: Trying yanan in cn  Ouch! Missing field/result... skipping.
# Attempt #520: Trying mataura in pf  Success!
# Attempt #521: Trying castro in cl  Success!
# Attempt #522: Trying tasiilaq in gl  Success!
# Attempt #523: Trying staden in be  Success!
# Attempt #524: Trying hobart in au  Success!
# Attempt #525: Trying the valley in ai  Success!
# Attempt #526: Trying megion in ru  Success!
# Attempt #527: Trying kluczbork in pl  Success!
# Attempt #528: Trying busselton in au  Success!
# Attempt #529: Trying new norfolk in au  Success!
# Attempt #530: Trying saint george in bm  Success!
# Attempt #531: Trying mogadishu in so  Success!
# Attempt #532: Trying ushuaia in ar  Success!
# Attempt #533: Trying olga in ru  Success!
# Attempt #534: Trying avarua in ck  Success!
# Attempt #535: Trying medea in dz  Success!
# Attempt #536: Trying souillac in mu  Success!
# Attempt #537: Trying nome in us  Success!
# Attempt #538: Trying albany in au  Success!
# Attempt #539: Trying tuatapere in nz  Success!
# Attempt #540: Trying miraflores in co  Success!
# Attempt #541: Trying verkhnetulomskiy in ru  Success!
# Attempt #542: Trying progreso in mx  Success!
# Attempt #543: Trying punta arenas in cl  Success!
# Attempt #544: Trying rikitea in pf  Success!
# Attempt #545: Trying langley park in us  Success!
# Attempt #546: Trying turki in ru  Success!
# Attempt #547: Trying ushuaia in ar  Success!
# Attempt #548: Trying kruisfontein in za  Success!
# Attempt #549: Trying talnakh in ru  Success!
# Attempt #550: Trying acarau in br  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 271
# ---------------------------------
# Attempt #551: Trying pavilosta in lv  Success!
# Attempt #552: Trying buala in sb  Success!
# Attempt #553: Trying bandarbeyla in so  Success!
# Attempt #554: Trying arlit in ne  Success!
# Attempt #555: Trying chippewa falls in us  Success!
# Attempt #556: Trying jamestown in sh  Success!
# Attempt #557: Trying tasiilaq in gl  Success!
# Attempt #558: Trying formoso do araguaia in br  Ouch! Missing field/result... skipping.
# Attempt #559: Trying busselton in au  Success!
# Attempt #560: Trying ushuaia in ar  Success!
# Attempt #561: Trying klaksvik in fo  Success!
# Attempt #562: Trying khatanga in ru  Success!
# Attempt #563: Trying katsuura in jp  Success!
# Attempt #564: Trying dikson in ru  Success!
# Attempt #565: Trying souillac in mu  Success!
# Attempt #566: Trying vostok in ru  Success!
# Attempt #567: Trying aklavik in ca  Success!
# Attempt #568: Trying karratha in au  Success!
# Attempt #569: Trying kaitangata in nz  Success!
# Attempt #570: Trying east london in za  Success!
# Attempt #571: Trying gisborne in nz  Success!
# Attempt #572: Trying bluff in nz  Success!
# Attempt #573: Trying qaanaaq in gl  Success!
# Attempt #574: Trying bambous virieux in mu  Success!
# Attempt #575: Trying nantucket in us  Success!
# Attempt #576: Trying sitka in us  Success!
# Attempt #577: Trying mataura in pf  Success!
# Attempt #578: Trying port alfred in za  Success!
# Attempt #579: Trying yulara in au  Success!
# Attempt #580: Trying new norfolk in au  Success!
# Attempt #581: Trying punta arenas in cl  Success!
# Attempt #582: Trying mattru in sl  Success!
# Attempt #583: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #584: Trying vaitupu in wf  Ouch! Missing field/result... skipping.
# Attempt #585: Trying esperance in au  Success!
# Attempt #586: Trying jamestown in sh  Success!
# Attempt #587: Trying tiruchchendur in in  Success!
# Attempt #588: Trying darlawn in in  Success!
# Attempt #589: Trying tessalit in ml  Success!
# Attempt #590: Trying samarai in pg  Success!
# Attempt #591: Trying acarau in br  Success!
# Attempt #592: Trying hobart in au  Success!
# Attempt #593: Trying barrow in us  Success!
# Attempt #594: Trying meulaboh in id  Success!
# Attempt #595: Trying barrow in us  Success!
# Attempt #596: Trying adzope in ci  Success!
# Attempt #597: Trying punta arenas in cl  Success!
# Attempt #598: Trying shepetivka in ua  Success!
# Attempt #599: Trying tello in co  Success!
# Attempt #600: Trying kurumkan in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 289
# ---------------------------------
# Attempt #601: Trying kavieng in pg  Success!
# Attempt #602: Trying rawson in ar  Success!
# Attempt #603: Trying ushuaia in ar  Success!
# Attempt #604: Trying muros in es  Success!
# Attempt #605: Trying lahij in ye  Success!
# Attempt #606: Trying solnechnyy in ru  Success!
# Attempt #607: Trying sola in vu  Success!
# Attempt #608: Trying nanortalik in gl  Success!
# Attempt #609: Trying longyearbyen in sj  Success!
# Attempt #610: Trying ribeira grande in pt  Success!
# Attempt #611: Trying narsaq in gl  Success!
# Attempt #612: Trying punta arenas in cl  Success!
# Attempt #613: Trying nanortalik in gl  Success!
# Attempt #614: Trying itarema in br  Success!
# Attempt #615: Trying coquimbo in cl  Success!
# Attempt #616: Trying almazar in uz  Success!
# Attempt #617: Trying bandarbeyla in so  Success!
# Attempt #618: Trying mataura in pf  Success!
# Attempt #619: Trying catamarca in ar  Success!
# Attempt #620: Trying batagay-alyta in ru  Success!
# Attempt #621: Trying sitka in us  Success!
# Attempt #622: Trying tuktoyaktuk in ca  Success!
# Attempt #623: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #624: Trying tasiilaq in gl  Success!
# Attempt #625: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #626: Trying puno in pe  Success!
# Attempt #627: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #628: Trying guaraniacu in br  Success!
# Attempt #629: Trying nikolskoye in ru  Success!
# Attempt #630: Trying yulara in au  Success!
# Attempt #631: Trying carnarvon in au  Success!
# Attempt #632: Trying beringovskiy in ru  Success!
# Attempt #633: Trying ilulissat in gl  Success!
# Attempt #634: Trying ostrovnoy in ru  Success!
# Attempt #635: Trying igarka in ru  Success!
# Attempt #636: Trying hermanus in za  Success!
# Attempt #637: Trying hilo in us  Success!
# Attempt #638: Trying ushuaia in ar  Success!
# Attempt #639: Trying saskylakh in ru  Success!
# Attempt #640: Trying egvekinot in ru  Success!
# Attempt #641: Trying ponta do sol in cv  Success!
# Attempt #642: Trying port elizabeth in za  Success!
# Attempt #643: Trying dicabisagan in ph  Success!
# Attempt #644: Trying port alfred in za  Success!
# Attempt #645: Trying barrow in us  Success!
# Attempt #646: Trying douentza in ml  Success!
# Attempt #647: Trying hermanus in za  Success!
# Attempt #648: Trying sola in vu  Success!
# Attempt #649: Trying torbay in ca  Success!
# Attempt #650: Trying port alfred in za  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 306
# ---------------------------------
# Attempt #651: Trying tahoua in ne  Success!
# Attempt #652: Trying toliary in mg  Ouch! Missing field/result... skipping.
# Attempt #653: Trying redlands in us  Success!
# Attempt #654: Trying nara in ml  Success!
# Attempt #655: Trying barcelos in br  Success!
# Attempt #656: Trying georgetown in sh  Success!
# Attempt #657: Trying hermanus in za  Success!
# Attempt #658: Trying port hardy in ca  Success!
# Attempt #659: Trying attawapiskat in ca  Ouch! Missing field/result... skipping.
# Attempt #660: Trying george in za  Success!
# Attempt #661: Trying shimoda in jp  Success!
# Attempt #662: Trying lolua in tv  Ouch! Missing field/result... skipping.
# Attempt #663: Trying ushuaia in ar  Success!
# Attempt #664: Trying ushuaia in ar  Success!
# Attempt #665: Trying brandon in us  Success!
# Attempt #666: Trying hamilton in bm  Success!
# Attempt #667: Trying vasilsursk in ru  Success!
# Attempt #668: Trying benjamin constant in br  Success!
# Attempt #669: Trying chuy in uy  Success!
# Attempt #670: Trying sorland in no  Success!
# Attempt #671: Trying colonial heights in us  Success!
# Attempt #672: Trying sitka in us  Success!
# Attempt #673: Trying oriximina in br  Success!
# Attempt #674: Trying atuona in pf  Success!
# Attempt #675: Trying lalomanu in ws  Ouch! Missing field/result... skipping.
# Attempt #676: Trying barrow in us  Success!
# Attempt #677: Trying broome in au  Success!
# Attempt #678: Trying jamestown in sh  Success!
# Attempt #679: Trying barrow in us  Success!
# Attempt #680: Trying severo-kurilsk in ru  Success!
# Attempt #681: Trying alofi in nu  Success!
# Attempt #682: Trying batagay in ru  Success!
# Attempt #683: Trying puerto ayora in ec  Success!
# Attempt #684: Trying atuona in pf  Success!
# Attempt #685: Trying hermanus in za  Success!
# Attempt #686: Trying ust-kuyga in ru  Success!
# Attempt #687: Trying saskylakh in ru  Success!
# Attempt #688: Trying dandong in cn  Success!
# Attempt #689: Trying lebu in cl  Success!
# Attempt #690: Trying lavrentiya in ru  Success!
# Attempt #691: Trying hualmay in pe  Success!
# Attempt #692: Trying myitkyina in mm  Success!
# Attempt #693: Trying codrington in ag  Success!
# Attempt #694: Trying punta arenas in cl  Success!
# Attempt #695: Trying nanortalik in gl  Success!
# Attempt #696: Trying ushuaia in ar  Success!
# Attempt #697: Trying walvis bay in na  Success!
# Attempt #698: Trying kirakira in sb  Success!
# Attempt #699: Trying barrow in us  Success!
# Attempt #700: Trying kazalinsk in kz  Ouch! Missing field/result... skipping.
# ---------------------------------
# Checking for duplicates.....resetting counter: 328
# ---------------------------------
# Attempt #701: Trying grajau in br  Success!
# Attempt #702: Trying toktogul in kg  Success!
# Attempt #703: Trying codrington in ag  Success!
# Attempt #704: Trying saint-philippe in re  Success!
# Attempt #705: Trying yellowknife in ca  Success!
# Attempt #706: Trying matto in jp  Ouch! Missing field/result... skipping.
# Attempt #707: Trying port alfred in za  Success!
# Attempt #708: Trying hilo in us  Success!
# Attempt #709: Trying hobart in au  Success!
# Attempt #710: Trying bredasdorp in za  Success!
# Attempt #711: Trying padang in id  Success!
# Attempt #712: Trying carnarvon in au  Success!
# Attempt #713: Trying saldanha in za  Success!
# Attempt #714: Trying busselton in au  Success!
# Attempt #715: Trying kaitangata in nz  Success!
# Attempt #716: Trying mankato in us  Success!
# Attempt #717: Trying barrow in us  Success!
# Attempt #718: Trying alice springs in au  Success!
# Attempt #719: Trying kenora in ca  Success!
# Attempt #720: Trying mataura in pf  Success!
# Attempt #721: Trying punta arenas in cl  Success!
# Attempt #722: Trying vaini in to  Success!
# Attempt #723: Trying bluff in nz  Success!
# Attempt #724: Trying denpasar in id  Success!
# Attempt #725: Trying hermanus in za  Success!
# Attempt #726: Trying mataura in pf  Success!
# Attempt #727: Trying saskylakh in ru  Success!
# Attempt #728: Trying shieli in kz  Success!
# Attempt #729: Trying ushuaia in ar  Success!
# Attempt #730: Trying kahului in us  Success!
# Attempt #731: Trying bredasdorp in za  Success!
# Attempt #732: Trying busselton in au  Success!
# Attempt #733: Trying bluff in nz  Success!
# Attempt #734: Trying rungata in ki  Ouch! Missing field/result... skipping.
# Attempt #735: Trying otautau in nz  Success!
# Attempt #736: Trying hilo in us  Success!
# Attempt #737: Trying karpogory in ru  Success!
# Attempt #738: Trying hobart in au  Success!
# Attempt #739: Trying kenai in us  Success!
# Attempt #740: Trying vaini in to  Success!
# Attempt #741: Trying bandarbeyla in so  Success!
# Attempt #742: Trying butaritari in ki  Success!
# Attempt #743: Trying jamestown in sh  Success!
# Attempt #744: Trying grand river south east in mu  Ouch! Missing field/result... skipping.
# Attempt #745: Trying upernavik in gl  Success!
# Attempt #746: Trying bredasdorp in za  Success!
# Attempt #747: Trying kahului in us  Success!
# Attempt #748: Trying albany in au  Success!
# Attempt #749: Trying yerbogachen in ru  Success!
# Attempt #750: Trying pevek in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 341
# ---------------------------------
# Attempt #751: Trying busselton in au  Success!
# Attempt #752: Trying tsihombe in mg  Ouch! Missing field/result... skipping.
# Attempt #753: Trying hualmay in pe  Success!
# Attempt #754: Trying bourail in nc  Success!
# Attempt #755: Trying busselton in au  Success!
# Attempt #756: Trying punta arenas in cl  Success!
# Attempt #757: Trying torbay in ca  Success!
# Attempt #758: Trying iskateley in ru  Success!
# Attempt #759: Trying poopo in bo  Success!
# Attempt #760: Trying lasa in cn  Success!
# Attempt #761: Trying qaanaaq in gl  Success!
# Attempt #762: Trying port alfred in za  Success!
# Attempt #763: Trying hithadhoo in mv  Success!
# Attempt #764: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #765: Trying puerto ayora in ec  Success!
# Attempt #766: Trying katsuura in jp  Success!
# Attempt #767: Trying upernavik in gl  Success!
# Attempt #768: Trying georgetown in sh  Success!
# Attempt #769: Trying caborca in mx  Success!
# Attempt #770: Trying bethel in us  Success!
# Attempt #771: Trying ushuaia in ar  Success!
# Attempt #772: Trying khandbari in np  Success!
# Attempt #773: Trying axim in gh  Success!
# Attempt #774: Trying punta arenas in cl  Success!
# Attempt #775: Trying benito juarez in mx  Success!
# Attempt #776: Trying torbay in ca  Success!
# Attempt #777: Trying saint anthony in ca  Success!
# Attempt #778: Trying margate in za  Success!
# Attempt #779: Trying kodiak in us  Success!
# Attempt #780: Trying busselton in au  Success!
# Attempt #781: Trying ushuaia in ar  Success!
# Attempt #782: Trying amapa in br  Success!
# Attempt #783: Trying samusu in ws  Ouch! Missing field/result... skipping.
# Attempt #784: Trying port alfred in za  Success!
# Attempt #785: Trying xiangfan in cn  Success!
# Attempt #786: Trying marcona in pe  Ouch! Missing field/result... skipping.
# Attempt #787: Trying sinnamary in gf  Success!
# Attempt #788: Trying poum in nc  Success!
# Attempt #789: Trying kamaishi in jp  Success!
# Attempt #790: Trying new norfolk in au  Success!
# Attempt #791: Trying cape town in za  Success!
# Attempt #792: Trying hasaki in jp  Success!
# Attempt #793: Trying ancud in cl  Success!
# Attempt #794: Trying vila franca do campo in pt  Success!
# Attempt #795: Trying carnarvon in au  Success!
# Attempt #796: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #797: Trying clyde river in ca  Success!
# Attempt #798: Trying geraldton in au  Success!
# Attempt #799: Trying fort saint james in ca  Success!
# Attempt #800: Trying imbituba in br  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 358
# ---------------------------------
# Attempt #801: Trying port hawkesbury in ca  Success!
# Attempt #802: Trying puerto ayora in ec  Success!
# Attempt #803: Trying grand gaube in mu  Success!
# Attempt #804: Trying lompoc in us  Success!
# Attempt #805: Trying faanui in pf  Success!
# Attempt #806: Trying hermanus in za  Success!
# Attempt #807: Trying los llanos de aridane in es  Success!
# Attempt #808: Trying punta arenas in cl  Success!
# Attempt #809: Trying santa rosa in bo  Success!
# Attempt #810: Trying bethel in us  Success!
# Attempt #811: Trying northam in au  Success!
# Attempt #812: Trying pisco in pe  Success!
# Attempt #813: Trying punta arenas in cl  Success!
# Attempt #814: Trying akdepe in tm  Success!
# Attempt #815: Trying touros in br  Success!
# Attempt #816: Trying inhambane in mz  Success!
# Attempt #817: Trying rikitea in pf  Success!
# Attempt #818: Trying rikitea in pf  Success!
# Attempt #819: Trying kapaa in us  Success!
# Attempt #820: Trying bethel in us  Success!
# Attempt #821: Trying lingao in cn  Success!
# Attempt #822: Trying mataura in pf  Success!
# Attempt #823: Trying hobyo in so  Success!
# Attempt #824: Trying saint george in bm  Success!
# Attempt #825: Trying ketchikan in us  Success!
# Attempt #826: Trying mataura in pf  Success!
# Attempt #827: Trying castro in cl  Success!
# Attempt #828: Trying severo-kurilsk in ru  Success!
# Attempt #829: Trying avarua in ck  Success!
# Attempt #830: Trying tateyama in jp  Success!
# Attempt #831: Trying mahebourg in mu  Success!
# Attempt #832: Trying jamestown in sh  Success!
# Attempt #833: Trying khatanga in ru  Success!
# Attempt #834: Trying nemyriv in ua  Success!
# Attempt #835: Trying beyneu in kz  Success!
# Attempt #836: Trying grindavik in is  Success!
# Attempt #837: Trying port blair in in  Success!
# Attempt #838: Trying chuy in uy  Success!
# Attempt #839: Trying tiarei in pf  Success!
# Attempt #840: Trying rikitea in pf  Success!
# Attempt #841: Trying salekhard in ru  Success!
# Attempt #842: Trying clyde river in ca  Success!
# Attempt #843: Trying bluff in nz  Success!
# Attempt #844: Trying butaritari in ki  Success!
# Attempt #845: Trying tabiauea in ki  Ouch! Missing field/result... skipping.
# Attempt #846: Trying rikitea in pf  Success!
# Attempt #847: Trying hofn in is  Success!
# Attempt #848: Trying hermanus in za  Success!
# Attempt #849: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #850: Trying mandera in ke  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 375
# ---------------------------------
# Attempt #851: Trying ballina in au  Success!
# Attempt #852: Trying vitim in ru  Success!
# Attempt #853: Trying hastings in us  Success!
# Attempt #854: Trying avarua in ck  Success!
# Attempt #855: Trying berbera in so  Success!
# Attempt #856: Trying aliaga in tr  Success!
# Attempt #857: Trying ushuaia in ar  Success!
# Attempt #858: Trying cayenne in gf  Success!
# Attempt #859: Trying sur in om  Success!
# Attempt #860: Trying rocha in uy  Success!
# Attempt #861: Trying ushuaia in ar  Success!
# Attempt #862: Trying makat in kz  Success!
# Attempt #863: Trying bambous virieux in mu  Success!
# Attempt #864: Trying vaini in to  Success!
# Attempt #865: Trying butaritari in ki  Success!
# Attempt #866: Trying albany in au  Success!
# Attempt #867: Trying barrow in us  Success!
# Attempt #868: Trying port alfred in za  Success!
# Attempt #869: Trying bambous virieux in mu  Success!
# Attempt #870: Trying dien bien in vn  Ouch! Missing field/result... skipping.
# Attempt #871: Trying rikitea in pf  Success!
# Attempt #872: Trying faanui in pf  Success!
# Attempt #873: Trying alice town in bs  Success!
# Attempt #874: Trying hermanus in za  Success!
# Attempt #875: Trying amderma in ru  Ouch! Missing field/result... skipping.
# Attempt #876: Trying bambous virieux in mu  Success!
# Attempt #877: Trying marti in cu  Success!
# Attempt #878: Trying cape town in za  Success!
# Attempt #879: Trying storforshei in no  Success!
# Attempt #880: Trying sharjah in ae  Success!
# Attempt #881: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #882: Trying castro in cl  Success!
# Attempt #883: Trying norman wells in ca  Success!
# Attempt #884: Trying mount isa in au  Success!
# Attempt #885: Trying narsaq in gl  Success!
# Attempt #886: Trying gravdal in no  Success!
# Attempt #887: Trying vasilsursk in ru  Success!
# Attempt #888: Trying wanaka in nz  Success!
# Attempt #889: Trying albany in au  Success!
# Attempt #890: Trying vardo in no  Success!
# Attempt #891: Trying baijiantan in cn  Success!
# Attempt #892: Trying lebu in cl  Success!
# Attempt #893: Trying avarua in ck  Success!
# Attempt #894: Trying saint-philippe in re  Success!
# Attempt #895: Trying ahipara in nz  Success!
# Attempt #896: Trying bredasdorp in za  Success!
# Attempt #897: Trying yirol in sd  Ouch! Missing field/result... skipping.
# Attempt #898: Trying ustka in pl  Success!
# Attempt #899: Trying eyl in so  Success!
# Attempt #900: Trying longyan in cn  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 396
# ---------------------------------
# Attempt #901: Trying road town in vg  Success!
# Attempt #902: Trying bom jesus in br  Success!
# Attempt #903: Trying ewa beach in us  Success!
# Attempt #904: Trying mildmay in ca  Success!
# Attempt #905: Trying omsukchan in ru  Success!
# Attempt #906: Trying aklavik in ca  Success!
# Attempt #907: Trying sinnamary in gf  Success!
# Attempt #908: Trying hilo in us  Success!
# Attempt #909: Trying hofn in is  Success!
# Attempt #910: Trying atuona in pf  Success!
# Attempt #911: Trying nagato in jp  Success!
# Attempt #912: Trying jamestown in sh  Success!
# Attempt #913: Trying hobart in au  Success!
# Attempt #914: Trying palmer in us  Success!
# Attempt #915: Trying saint-philippe in re  Success!
# Attempt #916: Trying lompoc in us  Success!
# Attempt #917: Trying ushuaia in ar  Success!
# Attempt #918: Trying qaanaaq in gl  Success!
# Attempt #919: Trying kapaa in us  Success!
# Attempt #920: Trying albany in au  Success!
# Attempt #921: Trying kapaa in us  Success!
# Attempt #922: Trying cape town in za  Success!
# Attempt #923: Trying jaciara in br  Success!
# Attempt #924: Trying apaxtla in mx  Ouch! Missing field/result... skipping.
# Attempt #925: Trying nikolskoye in ru  Success!
# Attempt #926: Trying airai in pw  Success!
# Attempt #927: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #928: Trying vardo in no  Success!
# Attempt #929: Trying grand river south east in mu  Ouch! Missing field/result... skipping.
# Attempt #930: Trying muncar in id  Success!
# Attempt #931: Trying kuche in cn  Ouch! Missing field/result... skipping.
# Attempt #932: Trying bethel in us  Success!
# Attempt #933: Trying hermanus in za  Success!
# Attempt #934: Trying zyryanka in ru  Success!
# Attempt #935: Trying barrow in us  Success!
# Attempt #936: Trying karkaralinsk in kz  Ouch! Missing field/result... skipping.
# Attempt #937: Trying tilichiki in ru  Success!
# Attempt #938: Trying albany in au  Success!
# Attempt #939: Trying pevek in ru  Success!
# Attempt #940: Trying vaitupu in wf  Ouch! Missing field/result... skipping.
# Attempt #941: Trying rikitea in pf  Success!
# Attempt #942: Trying lind in dk  Success!
# Attempt #943: Trying sibolga in id  Success!
# ...
# Attempt #1002: Trying cayenne in gf  Success!
# Attempt #1003: Trying airai in pw  Success!
# Attempt #1004: Trying lorengau in pg  Success!
# Attempt #1005: Trying ahipara in nz  Success!
# Attempt #1006: Trying jamestown in sh  Success!
# Attempt #1007: Trying luderitz in na  Success!
# Attempt #1008: Trying new norfolk in au  Success!
# Attempt #1009: Trying marcona in pe  Ouch! Missing field/result... skipping.
# Attempt #1010: Trying junin in ar  Success!
# Attempt #1011: Trying tazmalt in dz  Success!
# Attempt #1012: Trying cape town in za  Success!
# Attempt #1013: Trying kazachinskoye in ru  Success!
# Attempt #1014: Trying normandin in ca  Success!
# Attempt #1015: Trying nanortalik in gl  Success!
# Attempt #1016: Trying inhambane in mz  Success!
# Attempt #1017: Trying namibe in ao  Success!
# Attempt #1018: Trying jamestown in sh  Success!
# Attempt #1019: Trying jamestown in sh  Success!
# Attempt #1020: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #1021: Trying kuryk in kz  Success!
# Attempt #1022: Trying port lincoln in au  Success!
# Attempt #1023: Trying cape town in za  Success!
# Attempt #1024: Trying rikitea in pf  Success!
# Attempt #1025: Trying hobart in au  Success!
# Attempt #1026: Trying mataura in pf  Success!
# Attempt #1027: Trying kadykchan in ru  Ouch! Missing field/result... skipping.
# Attempt #1028: Trying yellowknife in ca  Success!
# Attempt #1029: Trying bayan in kw  Success!
# Attempt #1030: Trying hasaki in jp  Success!
# Attempt #1031: Trying ucluelet in ca  Success!
# Attempt #1032: Trying tura in ru  Success!
# Attempt #1033: Trying sinnar in sd  Success!
# Attempt #1034: Trying saquena in pe  Success!
# Attempt #1035: Trying carnarvon in au  Success!
# Attempt #1036: Trying araouane in ml  Success!
# Attempt #1037: Trying rikitea in pf  Success!
# Attempt #1038: Trying ponta do sol in cv  Success!
# Attempt #1039: Trying rikitea in pf  Success!
# Attempt #1040: Trying mataura in pf  Success!
# Attempt #1041: Trying sentyabrskiy in ru  Ouch! Missing field/result... skipping.
# Attempt #1042: Trying vila velha in br  Success!
# Attempt #1043: Trying attawapiskat in ca  Ouch! Missing field/result... skipping.
# Attempt #1044: Trying deputatskiy in ru  Success!
# Attempt #1045: Trying tocopilla in cl  Success!
# Attempt #1046: Trying port hardy in ca  Success!
# Attempt #1047: Trying airai in pw  Success!
# Attempt #1048: Trying cremona in it  Success!
# Attempt #1049: Trying tamsweg in at  Success!
# Attempt #1050: Trying flin flon in ca  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 443
# ---------------------------------
# Attempt #1051: Trying sakaraha in mg  Success!
# Attempt #1052: Trying thompson in ca  Success!
# Attempt #1053: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #1054: Trying tanete in id  Success!
# Attempt #1055: Trying hobart in au  Success!
# Attempt #1056: Trying louisbourg in ca  Ouch! Missing field/result... skipping.
# Attempt #1057: Trying cavalcante in br  Success!
# Attempt #1058: Trying hobart in au  Success!
# Attempt #1059: Trying ponta do sol in cv  Success!
# Attempt #1060: Trying rikitea in pf  Success!
# Attempt #1061: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1062: Trying atuona in pf  Success!
# Attempt #1063: Trying mirabad in af  Success!
# Attempt #1064: Trying albany in au  Success!
# Attempt #1065: Trying coquimbo in cl  Success!
# Attempt #1066: Trying bredasdorp in za  Success!
# Attempt #1067: Trying cheuskiny in ru  Ouch! Missing field/result... skipping.
# Attempt #1068: Trying nikolskoye in ru  Success!
# Attempt #1069: Trying hermanus in za  Success!
# Attempt #1070: Trying at-bashi in kg  Success!
# Attempt #1071: Trying kapaa in us  Success!
# Attempt #1072: Trying nikolskoye in ru  Success!
# Attempt #1073: Trying verkhnyaya sinyachikha in ru  Success!
# Attempt #1074: Trying te anau in nz  Success!
# Attempt #1075: Trying mataura in pf  Success!
# Attempt #1076: Trying severo-kurilsk in ru  Success!
# Attempt #1077: Trying hobart in au  Success!
# Attempt #1078: Trying kavieng in pg  Success!
# Attempt #1079: Trying filadelfia in py  Success!
# Attempt #1080: Trying tuktoyaktuk in ca  Success!
# Attempt #1081: Trying kruisfontein in za  Success!
# Attempt #1082: Trying nikolskoye in ru  Success!
# Attempt #1083: Trying kapaa in us  Success!
# Attempt #1084: Trying saskylakh in ru  Success!
# Attempt #1085: Trying albany in au  Success!
# Attempt #1086: Trying krasnoselkup in ru  Success!
# Attempt #1087: Trying bathsheba in bb  Success!
# Attempt #1088: Trying unai in br  Success!
# Attempt #1089: Trying port elizabeth in za  Success!
# Attempt #1090: Trying touros in br  Success!
# Attempt #1091: Trying thunder bay in ca  Success!
# Attempt #1092: Trying turayf in sa  Success!
# Attempt #1093: Trying bluff in nz  Success!
# Attempt #1094: Trying mar del plata in ar  Success!
# Attempt #1095: Trying isangel in vu  Success!
# Attempt #1096: Trying mataura in pf  Success!
# Attempt #1097: Trying nanortalik in gl  Success!
# Attempt #1098: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1099: Trying albany in au  Success!
# Attempt #1100: Trying lompoc in us  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 455
# ---------------------------------
# Attempt #1101: Trying magadan in ru  Success!
# Attempt #1102: Trying altay in cn  Success!
# Attempt #1103: Trying faanui in pf  Success!
# Attempt #1104: Trying aksu in kz  Success!
# Attempt #1105: Trying ushuaia in ar  Success!
# Attempt #1106: Trying vila franca do campo in pt  Success!
# Attempt #1107: Trying ushuaia in ar  Success!
# Attempt #1108: Trying bredasdorp in za  Success!
# Attempt #1109: Trying kollumerland in nl  Ouch! Missing field/result... skipping.
# Attempt #1110: Trying rikitea in pf  Success!
# Attempt #1111: Trying bunbury in au  Success!
# Attempt #1112: Trying lebu in cl  Success!
# Attempt #1113: Trying kapaa in us  Success!
# Attempt #1114: Trying hunza in pk  Ouch! Missing field/result... skipping.
# Attempt #1115: Trying vila franca do campo in pt  Success!
# Attempt #1116: Trying ayan in ru  Success!
# Attempt #1117: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #1118: Trying busselton in au  Success!
# Attempt #1119: Trying kodiak in us  Success!
# Attempt #1120: Trying kamenskoye in ru  Ouch! Missing field/result... skipping.
# Attempt #1121: Trying bethel in us  Success!
# Attempt #1122: Trying hobbs in us  Success!
# Attempt #1123: Trying port lincoln in au  Success!
# Attempt #1124: Trying bara in sd  Success!
# Attempt #1125: Trying kapaa in us  Success!
# Attempt #1126: Trying barawe in so  Ouch! Missing field/result... skipping.
# Attempt #1127: Trying ucluelet in ca  Success!
# Attempt #1128: Trying ambon in id  Success!
# Attempt #1129: Trying langsa in id  Success!
# Attempt #1130: Trying rikitea in pf  Success!
# Attempt #1131: Trying tuktoyaktuk in ca  Success!
# Attempt #1132: Trying east london in za  Success!
# Attempt #1133: Trying tautira in pf  Success!
# Attempt #1134: Trying kapaa in us  Success!
# Attempt #1135: Trying jamestown in sh  Success!
# Attempt #1136: Trying yershov in ru  Success!
# Attempt #1137: Trying rikitea in pf  Success!
# Attempt #1138: Trying bambous virieux in mu  Success!
# Attempt #1139: Trying anadyr in ru  Success!
# Attempt #1140: Trying hilo in us  Success!
# Attempt #1141: Trying albany in au  Success!
# Attempt #1142: Trying albany in au  Success!
# Attempt #1143: Trying santa rosa del sur in co  Success!
# Attempt #1144: Trying qaanaaq in gl  Success!
# Attempt #1145: Trying mataura in pf  Success!
# Attempt #1146: Trying barentsburg in sj  Ouch! Missing field/result... skipping.
# Attempt #1147: Trying coquimbo in cl  Success!
# Attempt #1148: Trying te anau in nz  Success!
# Attempt #1149: Trying codrington in ag  Success!
# Attempt #1150: Trying itarema in br  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 466
# ---------------------------------
# Attempt #1151: Trying bluff in nz  Success!
# Attempt #1152: Trying vao in nc  Success!
# Attempt #1153: Trying mataura in pf  Success!
# Attempt #1154: Trying hermanus in za  Success!
# Attempt #1155: Trying bandarbeyla in so  Success!
# Attempt #1156: Trying butaritari in ki  Success!
# Attempt #1157: Trying butaritari in ki  Success!
# Attempt #1158: Trying srednekolymsk in ru  Success!
# Attempt #1159: Trying barrow in us  Success!
# Attempt #1160: Trying alice springs in au  Success!
# Attempt #1161: Trying cape town in za  Success!
# Attempt #1162: Trying souillac in mu  Success!
# Attempt #1163: Trying arlit in ne  Success!
# Attempt #1164: Trying ushuaia in ar  Success!
# Attempt #1165: Trying ozgon in kg  Ouch! Missing field/result... skipping.
# Attempt #1166: Trying salalah in om  Success!
# Attempt #1167: Trying vaini in to  Success!
# Attempt #1168: Trying albany in au  Success!
# Attempt #1169: Trying damietta in eg  Success!
# Attempt #1170: Trying ushuaia in ar  Success!
# Attempt #1171: Trying sao joao da barra in br  Success!
# Attempt #1172: Trying cape town in za  Success!
# Attempt #1173: Trying bluff in nz  Success!
# Attempt #1174: Trying bandarbeyla in so  Success!
# Attempt #1175: Trying aklavik in ca  Success!
# Attempt #1176: Trying komsomolskiy in ru  Success!
# Attempt #1177: Trying rikitea in pf  Success!
# Attempt #1178: Trying illoqqortoormiut in gl  Ouch! Missing field/result... skipping.
# Attempt #1179: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1180: Trying kaitangata in nz  Success!
# Attempt #1181: Trying mys shmidta in ru  Ouch! Missing field/result... skipping.
# Attempt #1182: Trying mandalgovi in mn  Success!
# Attempt #1183: Trying rikitea in pf  Success!
# Attempt #1184: Trying butaritari in ki  Success!
# Attempt #1185: Trying bluff in nz  Success!
# Attempt #1186: Trying fukue in jp  Success!
# Attempt #1187: Trying bad doberan in de  Success!
# Attempt #1188: Trying rikitea in pf  Success!
# Attempt #1189: Trying thompson in ca  Success!
# Attempt #1190: Trying puerto ayora in ec  Success!
# Attempt #1191: Trying potgietersrus in za  Ouch! Missing field/result... skipping.
# Attempt #1192: Trying paita in pe  Success!
# Attempt #1193: Trying tsihombe in mg  Ouch! Missing field/result... skipping.
# Attempt #1194: Trying carnarvon in au  Success!
# Attempt #1195: Trying copiapo in cl  Success!
# Attempt #1196: Trying mataura in pf  Success!
# Attempt #1197: Trying shangzhi in cn  Success!
# Attempt #1198: Trying ushuaia in ar  Success!
# Attempt #1199: Trying alofi in nu  Success!
# Attempt #1200: Trying nishihara in jp  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 475
# ---------------------------------
# Attempt #1201: Trying ishlei in ru  Ouch! Missing field/result... skipping.
# Attempt #1202: Trying srednekolymsk in ru  Success!
# Attempt #1203: Trying provideniya in ru  Success!
# Attempt #1204: Trying sakakah in sa  Success!
# Attempt #1205: Trying khatanga in ru  Success!
# Attempt #1206: Trying bengkulu in id  Success!
# Attempt #1207: Trying lavrentiya in ru  Success!
# Attempt #1208: Trying inuvik in ca  Success!
# Attempt #1209: Trying qaqortoq in gl  Success!
# Attempt #1210: Trying ayagoz in kz  Success!
# Attempt #1211: Trying barrow in us  Success!
# Attempt #1212: Trying saint-philippe in re  Success!
# Attempt #1213: Trying mataura in pf  Success!
# Attempt #1214: Trying grindavik in is  Success!
# Attempt #1215: Trying albany in au  Success!
# Attempt #1216: Trying madinat sittah uktubar in eg  Success!
# Attempt #1217: Trying bryan in us  Success!
# Attempt #1218: Trying ushuaia in ar  Success!
# Attempt #1219: Trying rikitea in pf  Success!
# Attempt #1220: Trying taoudenni in ml  Success!
# Attempt #1221: Trying tuktoyaktuk in ca  Success!
# Attempt #1222: Trying bluff in nz  Success!
# Attempt #1223: Trying nikolskoye in ru  Success!
# Attempt #1224: Trying cap-aux-meules in ca  Success!
# Attempt #1225: Trying vila in vu  Success!
# Attempt #1226: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1227: Trying port elizabeth in za  Success!
# Attempt #1228: Trying ponta delgada in pt  Success!
# Attempt #1229: Trying bubaque in gw  Success!
# Attempt #1230: Trying hobart in au  Success!
# Attempt #1231: Trying atuona in pf  Success!
# Attempt #1232: Trying torbay in ca  Success!
# Attempt #1233: Trying airai in pw  Success!
# Attempt #1234: Trying tuatapere in nz  Success!
# Attempt #1235: Trying busselton in au  Success!
# Attempt #1236: Trying vila in vu  Success!
# Attempt #1237: Trying naze in jp  Success!
# Attempt #1238: Trying tuktoyaktuk in ca  Success!
# Attempt #1239: Trying tuktoyaktuk in ca  Success!
# Attempt #1240: Trying upernavik in gl  Success!
# Attempt #1241: Trying hermanus in za  Success!
# Attempt #1242: Trying belushya guba in ru  Ouch! Missing field/result... skipping.
# Attempt #1243: Trying obo in cf  Success!
# Attempt #1244: Trying bengkulu in id  Success!
# Attempt #1245: Trying tuatapere in nz  Success!
# Attempt #1246: Trying oktyabrskiy in ru  Success!
# Attempt #1247: Trying upernavik in gl  Success!
# Attempt #1248: Trying tuktoyaktuk in ca  Success!
# Attempt #1249: Trying beruwala in lk  Success!
# Attempt #1250: Trying gao in ml  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 490
# ---------------------------------
# Attempt #1251: Trying sibolga in id  Success!
# Attempt #1252: Trying eureka in us  Success!
# Attempt #1253: Trying bambous virieux in mu  Success!
# Attempt #1254: Trying qaanaaq in gl  Success!
# Attempt #1255: Trying castro in cl  Success!
# Attempt #1256: Trying saint-philippe in re  Success!
# Attempt #1257: Trying port elizabeth in za  Success!
# Attempt #1258: Trying dubbo in au  Success!
# Attempt #1259: Trying maragogi in br  Success!
# Attempt #1260: Trying riyadh in sa  Success!
# Attempt #1261: Trying klaksvik in fo  Success!
# Attempt #1262: Trying edson in ca  Success!
# Attempt #1263: Trying thompson in ca  Success!
# Attempt #1264: Trying naze in jp  Success!
# Attempt #1265: Trying punta arenas in cl  Success!
# Attempt #1266: Trying rikitea in pf  Success!
# Attempt #1267: Trying los banos in us  Success!
# Attempt #1268: Trying nisia floresta in br  Success!
# Attempt #1269: Trying nayagarh in in  Success!
# Attempt #1270: Trying dolbeau in ca  Ouch! Missing field/result... skipping.
# Attempt #1271: Trying atambua in id  Success!
# Attempt #1272: Trying qaanaaq in gl  Success!
# Attempt #1273: Trying tsiroanomandidy in mg  Success!
# Attempt #1274: Trying punta arenas in cl  Success!
# Attempt #1275: Trying jamestown in sh  Success!
# Attempt #1276: Trying airai in pw  Success!
# Attempt #1277: Trying thompson in ca  Success!
# Attempt #1278: Trying mahebourg in mu  Success!
# Attempt #1279: Trying port alfred in za  Success!
# Attempt #1280: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1281: Trying rabo de peixe in pt  Success!
# Attempt #1282: Trying hobart in au  Success!
# Attempt #1283: Trying yellowknife in ca  Success!
# Attempt #1284: Trying ushuaia in ar  Success!
# Attempt #1285: Trying lompoc in us  Success!
# Attempt #1286: Trying fortuna in us  Success!
# Attempt #1287: Trying attawapiskat in ca  Ouch! Missing field/result... skipping.
# Attempt #1288: Trying ushuaia in ar  Success!
# Attempt #1289: Trying moranbah in au  Success!
# Attempt #1290: Trying gravdal in no  Success!
# Attempt #1291: Trying taolanaro in mg  Ouch! Missing field/result... skipping.
# Attempt #1292: Trying busselton in au  Success!
# Attempt #1293: Trying berlevag in no  Success!
# Attempt #1294: Trying ancud in cl  Success!
# Attempt #1295: Trying albany in au  Success!
# Attempt #1296: Trying amderma in ru  Ouch! Missing field/result... skipping.
# Attempt #1297: Trying kapaa in us  Success!
# Attempt #1298: Trying codrington in ag  Success!
# Attempt #1299: Trying punta arenas in cl  Success!
# Attempt #1300: Trying baykalsk in ru  Success!
# ---------------------------------
# Checking for duplicates.....resetting counter: 501
# ---------------------------------
# ----------------------------------------------
# End of run summary statistics
# Total records: 501
# Number of requests returning no results: 109
# Number of duplicates removed: 691

# %%
# Check results
df_weather_data
# Out:
#                  City Country_Code Input_Lat Input_Lon Actual_Lat Actual_Lon  \
# 0              hobart           AU       -73       138   -42.8794    147.329
# 1              albany           US       -78        98    42.6001   -73.9662
# 2           esperance           AU       -29       124   -33.8667      121.9
# 3              dikson           RU        72        75    73.5069    80.5464
# 5                hilo           US        34      -143    19.7297    -155.09
# ...               ...          ...       ...       ...        ...        ...
# 1271          atambua           ID       -10       127    -9.1061    124.892
# 1273  tsiroanomandidy           MG       -19        46   -18.7667    46.0333
# 1281    rabo de peixe           PT        43       -23       37.8   -25.5833
# 1289         moranbah           AU       -22       147   -22.0016    148.047
# 1300         baykalsk           RU        51       104    51.5058    104.147
#
#      MaxTemp Humidity Cloudiness Wind_Speed           Date_Time
# 0       55.4       71         98       9.22  5/1/2021 - 9:16:29
# 1         41       70         23       1.01  5/1/2021 - 9:16:30
# 2       55.4       88          5       5.75  5/1/2021 - 9:18:26
# 3      24.85       88         94       7.83  5/1/2021 - 9:17:38
# 5       69.8       73         40       4.61   5/1/2021 - 9:17:0
# ...      ...      ...        ...        ...                 ...
# 1271   71.98       84         97       5.03  5/1/2021 - 9:22:10
# 1273   75.97       67         79       4.68  5/1/2021 - 9:22:10
# 1281    60.8       77         75      10.36  5/1/2021 - 9:22:11
# 1289   63.64       87          5       9.48  5/1/2021 - 9:22:12
# 1300   34.29       99        100       1.28  5/1/2021 - 9:22:14
#
# [501 rows x 11 columns]

# %%
# Add "Hemisphere" column
df_weather_data["Hemisphere"] = ""
for index, row in df_weather_data.iterrows():   
    if df_weather_data.loc[index,"Actual_Lat"]>0:
        df_weather_data.loc[index, "Hemisphere"] = "Northern"
    else:
        df_weather_data.loc[index, "Hemisphere"] = "Southern" 
# Save results as csv file

df_weather_data.to_csv("../output_data/cities_1.csv")

# %%
# Are you getting coverage of the full gamut of latitudes? 
fig1, axes = plt.subplots(2,1,sharex=True, sharey=True)
axes[0].hist(lat[:x].astype(float), bins = 50, range = (-90,90), facecolor='r', alpha=0.5)
axes[1].hist(df_weather_data["Actual_Lat"].astype(float), bins = 50, range = (-90,90),facecolor='g', alpha=0.75)
axes[1].set(xlabel = "Latitude")
axes[0].set(ylabel = "Frequency")
axes[1].set(ylabel = "Frequency")
axes[0].set(title = "Latitude <Requests>")
axes[1].set(title = "Latitude <Returns>")
fig1.suptitle('Coverage of latitudes ', fontsize=12)
print("Conclusion:")
print("1. Random lat,long generator produces as a uniform distribution of latitude <Requests>")
print("2. <Returns> can only be generated where cities are. This suggests no cities above 80' N (Artic Circle) and") 
print("below -60' S (Antarctica) which seems reasonable.")
plt.show()
# Are you getting coverage of the full gamut of longitudes? 
fig2, axes = plt.subplots(2,1,sharex=True, sharey=True)
axes[0].hist(lon[:x].astype(float), bins = 50, range = (-180,180), facecolor='r', alpha=0.5)
axes[1].hist(df_weather_data["Actual_Lon"].astype(float), bins = 50, range = (-180,180),facecolor='g', alpha=0.75)
axes[1].set(xlabel = "Longitude")
axes[0].set(ylabel = "Frequency")
axes[1].set(ylabel = "Frequency")
axes[0].set(title = "Longitude <Requests>")
axes[1].set(title = "Longitude <Returns>")
fig2.suptitle('Coverage of longitudes ', fontsize=12)
print("Conclusion:")
print("1. Random lat,long generator produces a uniform distribution of longitude <Requests>")
print("2. <Returns> can only be generated where cities are. This suggests cities are distributed across all longitudes")
print("with concentrations in certain areas (e.g. Europe, North America, SE Asia)")
plt.show()
print("----------------------------------------------------------------------------------------------")
print("Overall conclusion: Random lat,long generator produced random and well distributed data points")
print("----------------------------------------------------------------------------------------------")
fig1.savefig('../Images/LatHist.png')
fig2.savefig('../Images/LongHist.png')
# Out:
# Conclusion:
# 1. Random lat,long generator produces as a uniform distribution of latitude <Requests>
# 2. <Returns> can only be generated where cities are. This suggests no cities above 80' N (Artic Circle) and
# below -60' S (Antarctica) which seems reasonable.
# Conclusion:
# 1. Random lat,long generator produces a uniform distribution of longitude <Requests>
# 2. <Returns> can only be generated where cities are. This suggests cities are distributed across all longitudes
# with concentrations in certain areas (e.g. Europe, North America, SE Asia)
# ----------------------------------------------------------------------------------------------
# Overall conclusion: Random lat,long generator produced random and well distributed data points
# ----------------------------------------------------------------------------------------------

# %%
# Your first requirement is to create a series of scatter plots to showcase the following relationships:

# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
# After each plot add a sentence or too explaining what the code is and analyzing.


scatter_list = ["MaxTemp","Humidity","Cloudiness","Wind_Speed"]
comments = {"MaxTemp":"Looking at relationship/correlation between Temp (F) and Latitude", 
            "Humidity":"Looking at relationship/correlation between Humidity and Latitude",
           "Cloudiness":"Looking at relationship/correlation between Cloudiness(%) and Latitude",
           "Wind_Speed":"Looking at relationship/correlation between Wind Speed (mph) and Latitude"}

for scatter in scatter_list:
    # fig, axes
    y_values = df_weather_data[scatter].astype(float)
    x_values = df_weather_data["Actual_Lat"].astype(float)
    plt.ylabel(scatter)
    plt.title(comments[scatter])
    plt.scatter(x_values,y_values,marker="o", facecolors="red", edgecolors="black", s=10, alpha=0.75)
    plt.xlabel('Latitude')
    plt.grid()
#     print(scatter)
#     print(comments[scatter])
    filename = f"Scatter_Plot_{scatter}_verus_Latitude.png"
    path = f"../Images/ + {filename}"
    plt.savefig(path)
    plt.show()

# %%
# Your second requirement is to run linear regression on each relationship, only this time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):

# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude

# After each pair of plots explain what the linear regression is modeling such as any relationships you notice and any other analysis you may have.


plot_variables = ["MaxTemp","Humidity","Cloudiness","Wind_Speed"]
hemispheres = ["Northern","Southern"]
comments = {"MaxTemp": "Both  hemispheres show correlations of Temp reducing with distance from equator. Two points of interest: the models predict different temperatures at the equator (y-intercept) and have different slopes",
           "Humidity":"No correlation", "Cloudiness": "No correlation", "Wind_Speed": "No correlation"}
           

for Variable in plot_variables:
    for Hemisphere in hemispheres:
        x_values = df_weather_data.loc[lambda x: x.Hemisphere == Hemisphere]["Actual_Lat"].astype(float)
        y_values = df_weather_data.loc[lambda x: x.Hemisphere == Hemisphere][Variable].astype(float)
        (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
        regress_values = x_values * slope + intercept
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        plt.scatter(x_values,y_values,marker="o", facecolors="red", edgecolors="black", s=10, alpha=0.75)
        plt.plot(x_values,regress_values,"r-")
        # ann_x = x_values.median(); ann_y = y_values.median()
        # plt.annotate(line_eq,(ann_x,ann_y),fontsize=12,color="red")
        plt.xlabel('Latitude')
        plt.ylabel(Variable)
        plt.title(f"{Variable} versus Latitude in the {Hemisphere} hemisphere")
        print(f"The r-squared is: {round(rvalue**2,3)}")
        print(line_eq)
        filename = f"Regression_{Variable}_verus_Latitude_in_{Hemisphere}_hemisphere.png"
        path = f"../Images/ + {filename}"
        plt.savefig(path)
        plt.show()
    print(comments[Variable])
# Out:
# The r-squared is: 0.763
# y = -0.99x + 98.0
# The r-squared is: 0.594
# y = 0.65x + 84.48
# Both  hemispheres show correlations of Temp reducing with distance from equator. Two points of interest: the models predict different temperatures at the equator (y-intercept) and have different slopes
# The r-squared is: 0.043
# y = 0.25x + 55.21
# The r-squared is: 0.021
# y = 0.19x + 75.36
# No correlation
# The r-squared is: 0.03
# y = 0.32x + 45.31
# The r-squared is: 0.104
# y = 0.95x + 71.3
# No correlation
# The r-squared is: 0.009
# y = 0.03x + 7.34
# The r-squared is: 0.0
# y = -0.01x + 7.1
# No correlation
